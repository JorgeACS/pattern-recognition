# %% [markdown]
# <hr style="border-width: 3px;">
#
# ### Proyecto de Magic
#
# ## Jorge Arturo Carvajal Siller
#
# El objectivo de este proyecto es:
#
# 1) Poder establecer una relacion de sinergia entre cualesquiera dos cartas del juego "Magic The Gathering" (MTG)
#
# 2) Recomendar cartas que podrian ser utiles dado un conjunto de cartas en particular (Usando la relacion previamente establecida como base)
#
# Encontrar este tipo de sinergia puede llegar a ser complicado, considerando que se han sacado aproximadamente 16000 cartas a lo largo de su historia. Esto puede ser algo facil para alguien que comprende y lleva tiempo jugando, pero puede ser muy pesado para jugadores que quieren empezar o simplemente no tienen mucho conocimiento de las cartas que existen.
#
# Ejemplos de cartas con buena sinergia:
#
# <a> <img src="http://www.manaleak.com/mtguk/files/2014/07/bestfriendteam2.png" href="http://www.manaleak.com/" ></a>
#
# <a> <img src="http://www.manaleak.com/mtguk/files/2013/09/Quillspike-Infinite.jpg" href="http://www.manaleak.com/"></a>
#
# Si bien los ejemplos de arriba son algo intuitivos, ya que hay una ganancia inmediata, hay ciertas combinaciones que no son muy faciles de detectar, e incluso pueden tardar varios turnos en desarrollarse.
#
# ![](images/kessig-nyx.png)
#
# Base de datos utilizada:

# %%
import numpy as np 
import pandas as pd 
import pprint
import os
import sys
os.chdir('Data sets')
#Lectura de datos en bruto
raw = pd.read_json("Magic/AllSets-x.json")

# %%
import operator
import numpy

# %% [markdown]
# El primer paso de limpieza de datos fue quitar los sets de broma (Unhinged y Unglued), ya que estas cartas no son legales dentro del juego
#
# <a href="http://chameleonsden.com" title="Chameleon's Den - Video Games, Anime Collectibles and more!"><img src="http://chameleonsden.com/products/items/magic_the_gathering_unglued_card_chaos_confetti/Chaos_Confetti_card_from_Unglued.jpg" alt="Chameleon's Den - Video Games, Anime Collectibles and more!"></a>

# %%
#raw = raw.drop(['pREL'],1)
raw = raw.drop(['UGL'],1)

raw = raw.drop(['UNH'],1)

# %%
def stopWord(word):
    stopWords = ["its","may","the","of","a","if","or","and","them",
                 "this","that","you","this","turn","those",
                 "be","at","your","to","creature","it","in","has",
                 "until","on","onto","when","where","an","as","for","with"]
    if word in stopWords:
        return True
    return False
def colorString(colorId):
    colorString = ""
    
    if(colorId&1 == 1):
        colorString+="W"
    if(colorId&2 == 2):
        colorString+="B"
    if(colorId&4 == 4):
        colorString+="G"
    if(colorId&8 == 8):
        colorString+="R"
    if(colorId&16 == 16):
        colorString+="U"
    if (colorId == 0):
        colorString="Colorless"
    return colorString
def formatWord(word):
    word = word.lower()
    word = word.replace('.','')
    word = word.replace(',','')
    word = word.replace('"','')
    word = word.replace('=','')
    word = word.replace("'s",'')
    word = word.replace(':','')
    word = word.replace(';','')
    word = word.replace('(','')
    word = word.replace(')','')
    word = word.replace('[','')
    word = word.replace(']','')
    return word
#raw.describe
sets = raw.keys()
cards = []
derps = {}

for set in sets:
    for card in raw[set].cards:
        derps[card['name']] = card

# %% [markdown]
# Una vez que insertamos todas las cartas en un solo diccionario, eliminamos cartas que no son legales.

# %%
del derps['Shichifukujin Dragon']
del derps['1996 World Champion']
del derps['Ass Whuppin\'']

# %% [markdown]
# Ademas, eliminaremos las tierras basicas, ya que no son relevantes al momento de verificar relacion entre cartas

# %%
deleteableEntries = []
#Eliminando tierras
for card in derps.values():
    if card.get('supertypes') is not None and "Basic" in card["supertypes"]:
        deleteableEntries.append(card['name'])
for name in deleteableEntries:
    del derps[name]

# %% [markdown]
# Ahora calcularemos los siguientes valores para cada una de las cartas en el juego:
#
# -color
# -power
# -toughness
#
# y asi sacar la cantidad de cartas de cada color, asi como el poder y resistencia promedio de cada color.

# %%
generalWords = {}
specificPower = {}
specificToughness = {}
specificWords = {}
specificCMC = {}

uniqueColors = {}
uniqueColors['Colorless'] = 0
for card in derps.values():
    uniqueColor = 0
    color = ""
    #check if card has a color
    if(card.get('colors') is None):
        #card is colorless
        ###TODO: Make a difference between colorless and devoid cards
        uniqueColors['Colorless'] +=1
        color = "Colorless"
    else:
        #Card has a color
        #Start building an identifier that represents the card's color uniquely
        for c in card['colors']:
            if(c == 'White'):
                uniqueColor+=1
            elif(c == 'Black'):
                 uniqueColor+=2
            elif(c == 'Green'):
                uniqueColor+=4
            elif(c == 'Red'):
                uniqueColor+=8
            elif(c == 'Blue'):
                uniqueColor+=16
        color = colorString(uniqueColor)
        #if(colorChido == 16):
        #    pprint.pprint(i['name'])
        if(uniqueColors.get(color) is None):
            uniqueColors[color] = 1
        else:
            uniqueColors[color]+=1
    #Check if card has effect text
    if(card.get('text') is not None):
        #Split the text into words
        text = card['text']
        text = text.replace("First strike","first-strike")
        text = text.replace("first strike","first-strike")
        text = text.replace("Double strike","double-strike")
        text = text.replace("double strike","double-strike")
        text = text.split()
        #Iterate over each word
        for word in text:
            #format word
            # formatWord(word) removes all character
            # that could alter the way the word is intepreted.
            # Example: '.', ',', '(',')', etc.
            word = formatWord(word)
            if(word == "his" or word == "her"):
                word = "their"
            # Check if word is a stop word
            # A stop word is a word that is repeated too often
            # in the language, and for the most part are unnecesary
            # to determine the value of an effect.
            # Example 'you', 'an', 'the', 'a', 'of', etc.
            if stopWord(word):
                continue
            # Now we add it to the list of general words (words shared by all cards)
            if(generalWords.get(word) is None):
                generalWords[word] = 1
            else:
                generalWords[word] += 1
            # and to the list of specific words (words shared by cards of the same color)
            if(specificWords.get(color) is None):
                specificWords[color] = {}
                
            if(specificWords[color].get(word) is None):
                specificWords[color][word] = 1
            else:
                specificWords[color][word] += 1
    #Check if card has Converted Mana Cost
    if(card.get('cmc') is not None):
        if (specificCMC.get(color) is None):
            specificCMC[color] = [int(card['cmc'])]
        else:
            specificCMC[color].append(int(card['cmc']))
    #Check if card has Power
    if(card.get('power') is not None):
        #check if power or toughness are not integers (Ej. */*+1)
        #All cards with power have toughness (creature cards)
        try:
            int(card['power'])
            int(card['toughness'])
        except ValueError:
            #If not, don't add it to the power and toughness array
            continue
        #else, add
        if(specificPower.get(color) is None):
            specificPower[color] = [int(card['power'])]
            specificToughness[color] = [int(card['toughness'])]
        else:
            specificPower[color].append(int(card['power']))
            specificToughness[color].append(int(card['toughness']))

# %% [markdown]
# # Estadisticas de cartas en MTG
#
# ## Clasificacion de colores:
#
# -W , White : Color que se concentra en vida, control de campo, creaturas, tokens.
#
# -B , Black : Color que se concentra en control individual, descartar, sacrificios
#
# G , Green : Color que se concentra en mana, creaturas fuertes, contadores
#
# R , Red   : Color que se concentra en daño, control de campo,
#
# U , Blue  : Color que se concentra en control con counters, creaturas dificiles de eliminar, jalar cartas
#
# ## Ademas, hay cartas que tienen dos o mas combinaciones de colores. Estos tipicamente combinan las caracteristicas principales de ambos colores.
#
# BG, Black and Green (Golgari) : Cartas centradas en el cementerio, beneficiar creaturas con destruccion
#
# BU, Black and Blue (Derp): Cartas centradas en control absoluto (counters, descartar, millear)
#
# RU, Red and Blue (Derp2): Cartas centradas en spells, tanto daño como counters

# %%
pprint.pprint("Cantidad de cartas por color: ")
pprint.pprint(sum(color for color in uniqueColors.values()))
pprint.pprint(uniqueColors)
cardStats = {}
print()
pprint.pprint("10 palabras mas usadas en cada color: ")
#we iterate over all color sets
for words in specificWords:
    pprint.pprint(words)
    sortedWords = sorted(specificWords[words].items(),key=operator.itemgetter(1))
    #we print the 10 most popular words in this set
    for i in range(10):
        pprint.pprint(sortedWords[-1-i])
    print()
for color in coloresUnicos:
    cardStats[color] = {}
    cardStats[color]["# of cards: "] = coloresUnicos[color]
    sortedCMC = sorted(specificCMC[color])
    
    cardStats[color]["CMC"] = {"Mean CMC" : np.sum(specificCMC[color])/len(specificCMC[color]),
                               "Max CMC" : sortedCMC[-1],
                               "Min CMC" : sortedCMC[0],
                               "Median CMC" : sortedCMC[len(sortedCMC)//2] }
    sortedPower = sorted(specificPower[color])
    
    cardStats[color]["Power"] = {"Mean Power" : np.sum(specificPower[color])/len(specificPower[color]),
                                 "Max Power" : sortedPower[-1], 
                                 "Min Power" : sortedPower[0], 
                                 "Median Power" : sortedPower[len(sortedPower)//2] }
    sortedToughness = sorted(specificToughness[color])
    
    cardStats[color]["Toughness"] = {"Mean Toughness" : np.sum(specificToughness[color])/len(specificToughness[color]),
                                     "Max Toughness" : sortedToughness[-1],
                                     "Min Toughness" : sortedToughness[0],
                                     "Median Toughness" : sortedToughness[len(sortedToughness)//2] }
pprint.pprint(cardStats)
# Out:
# 'Cantidad de cartas por color: '
# 16508
# {'B': 2484,
#  'BG': 99,
#  'BGR': 29,
#  'BGRU': 1,
#  'BGU': 13,
#  'BR': 153,
#  'BRU': 31,
#  'BU': 156,
#  'Colorless': 2564,
#  'G': 2493,
#  'GR': 155,
#  'GRU': 14,
#  'GU': 98,
#  'R': 2487,
#  'RU': 99,
#  'U': 2456,
#  'W': 2504,
#  'WB': 104,
#  'WBG': 13,
#  'WBGR': 1,
#  'WBGRU': 22,
#  'WBGU': 1,
#  'WBR': 13,
#  'WBRU': 1,
#  'WBU': 29,
#  'WG': 159,
#  'WGR': 29,
#  'WGRU': 1,
#  'WGU': 30,
#  'WR': 101,
#  'WRU': 12,
#  'WU': 156}
#
# '10 palabras mas usadas en cada color: '
# 'W'
# ('target', 940)
# ('battlefield', 760)
# ('control', 728)
# ('creatures', 704)
# ('damage', 649)
# ('card', 567)
# ('end', 523)
# ('flying', 517)
# ('put', 488)
# ('with', 476)
#
# 'U'
# ('target', 1222)
# ('card', 1171)
# ('their', 772)
# ('battlefield', 652)
# ('flying', 642)
# ('player', 638)
# ('spell', 631)
# ('library', 613)
# ('control', 583)
# ('cards', 582)
#
# 'B'
# ('target', 1131)
# ('card', 1125)
# ('player', 863)
# ('battlefield', 747)
# ('life', 639)
# ('from', 639)
# ('graveyard', 581)
# ('end', 542)
# ('put', 537)
# ('creatures', 511)
#
# 'R'
# ('target', 1242)
# ('damage', 1234)
# ('deals', 997)
# ('player', 957)
# ('end', 705)
# ('each', 611)
# ('control', 569)
# ('card', 569)
# ('battlefield', 555)
# ('creatures', 496)
#
# 'G'
# ('battlefield', 904)
# ('put', 860)
# ('card', 821)
# ('target', 806)
# ('control', 635)
# ('with', 569)
# ('each', 547)
# ('+1/+1', 544)
# ('end', 520)
# ('library', 503)
#
# 'Colorless'
# ('{t}', 1540)
# ('mana', 1301)
# ('battlefield', 1093)
# ('card', 939)
# ('pool', 917)
# ('add', 897)
# ('target', 860)
# ('put', 681)
# ('enters', 674)
# ('control', 654)
#
# 'BU'
# ('their', 121)
# ('card', 117)
# ('player', 91)
# ('target', 87)
# ('cards', 70)
# ('library', 58)
# ('hand', 51)
# ('graveyard', 47)
# ('from', 42)
# ('top', 40)
#
# 'WR'
# ('target', 53)
# ('damage', 51)
# ('creatures', 47)
# ('end', 41)
# ('control', 36)
# ('whenever', 31)
# ('deals', 31)
# ('player', 26)
# ('battlefield', 22)
# ('gets', 22)
#
# 'WGU'
# ('target', 21)
# ('control', 14)
# ('end', 13)
# ('flying', 13)
# ('card', 13)
# ('battlefield', 11)
# ('whenever', 9)
# ('put', 9)
# ('untap', 8)
# ('+1/+1', 8)
#
# 'BR'
# ('target', 89)
# ('player', 79)
# ('damage', 72)
# ('deals', 58)
# ('card', 51)
# ('battlefield', 50)
# ('end', 39)
# ('each', 36)
# ('hand', 34)
# ('+1/+1', 34)
#
# 'GR'
# ('target', 76)
# ('battlefield', 64)
# ('damage', 55)
# ('control', 51)
# ('end', 50)
# ('deals', 50)
# ('player', 39)
# ('enters', 38)
# ('with', 38)
# ('+1/+1', 37)
#
# 'WBU'
# ('target', 19)
# ('life', 17)
# ('flying', 12)
# ('battlefield', 11)
# ('gain', 11)
# ('card', 10)
# ('artifact', 10)
# ('â€¢', 9)
# ('from', 9)
# ('cards', 9)
#
# 'BGR'
# ('player', 14)
# ('target', 14)
# ('put', 9)
# ('sacrifice', 8)
# ('each', 8)
# ('damage', 8)
# ('â€¢', 8)
# ('gets', 8)
# ('card', 8)
# ('flying', 8)
#
# 'BRU'
# ('player', 25)
# ('card', 19)
# ('whenever', 18)
# ('target', 16)
# ('battlefield', 12)
# ('damage', 11)
# ('put', 10)
# ('life', 10)
# ('cards', 10)
# ('deals', 9)
#
# 'WU'
# ('target', 71)
# ('flying', 64)
# ('card', 58)
# ('battlefield', 48)
# ('control', 47)
# ('cast', 42)
# ('whenever', 38)
# ('put', 37)
# ('hand', 36)
# ("can't", 36)
#
# 'WGR'
# ('target', 13)
# ('control', 12)
# ('battlefield', 12)
# ('put', 11)
# ('mana', 9)
# ('damage', 9)
# ('â€¢', 9)
# ('x', 8)
# ('land', 8)
# ('whenever', 8)
#
# 'GU'
# ('card', 52)
# ('battlefield', 46)
# ('target', 41)
# ('put', 39)
# ('cast', 35)
# ('control', 32)
# ('with', 31)
# ('counter', 31)
# ('+1/+1', 30)
# ('enters', 28)
#
# 'BG'
# ('card', 65)
# ('target', 55)
# ('graveyard', 50)
# ('put', 47)
# ('from', 42)
# ('battlefield', 39)
# ('end', 30)
# ('with', 24)
# ('whenever', 23)
# ('+1/+1', 23)
#
# 'WG'
# ('control', 69)
# ('put', 64)
# ('battlefield', 62)
# ('+1/+1', 46)
# ('target', 42)
# ('card', 40)
# ('creatures', 36)
# ('end', 33)
# ('token', 30)
# ('whenever', 30)
#
# 'RU'
# ('target', 71)
# ('card', 46)
# ('spell', 45)
# ('cast', 44)
# ('damage', 33)
# ('end', 33)
# ('deals', 30)
# ('cards', 29)
# ('flying', 27)
# ('instant', 27)
#
# 'WB'
# ('life', 80)
# ('target', 57)
# ('battlefield', 49)
# ('gain', 35)
# ('from', 35)
# ('card', 34)
# ('control', 33)
# ('each', 33)
# ('whenever', 28)
# ('exile', 28)
#
# 'WBGRU'
# ('card', 15)
# ('library', 12)
# ('control', 11)
# ('put', 10)
# ('each', 9)
# ('target', 7)
# ('sliver', 6)
# ('into', 6)
# ('land', 6)
# ('from', 6)
#
# 'WBR'
# ('battlefield', 8)
# ('put', 7)
# ('opponent', 7)
# ('whenever', 7)
# ('card', 6)
# ('attacks', 6)
# ('haste', 5)
# ('damage', 5)
# ('end', 5)
# ('control', 5)
#
# 'BGU'
# ('cards', 12)
# ('card', 11)
# ('put', 8)
# ('battlefield', 7)
# ('draw', 7)
# ('whenever', 7)
# ('graveyard', 6)
# ('into', 6)
# ('library', 6)
# ('one', 6)
#
# 'GRU'
# ('card', 10)
# ('battlefield', 8)
# ('control', 8)
# ('put', 8)
# ('cast', 7)
# ('target', 6)
# ('whenever', 6)
# ('spell', 6)
# ('library', 6)
# ('cards', 5)
#
# 'WRU'
# ('control', 8)
# ('target', 7)
# ('end', 6)
# ('noncreature', 5)
# ('creatures', 5)
# ('cast', 5)
# ('whenever', 5)
# ('flying', 5)
# ('card', 4)
# ('gain', 4)
#
# 'WBG'
# ('+1/+1', 8)
# ('battlefield', 8)
# ('each', 7)
# ('put', 7)
# ('control', 7)
# ('card', 6)
# ('target', 6)
# ('two', 5)
# ('one', 5)
# ('counter', 5)
#
# 'WBGR'
# ('control', 1)
# ('land', 1)
# ('each', 1)
# ('battlefield', 1)
# ('token', 1)
# ('sand', 1)
# ('colorless', 1)
# ('1/1', 1)
# ('put', 1)
# ('player', 1)
#
# 'BGRU'
# ('nephilim', 2)
# ('glint-eye', 2)
# ('end', 1)
# ('+1/+1', 1)
# ('gets', 1)
# ('card', 1)
# ('discard', 1)
# ('{1}', 1)
# ('cards', 1)
# ('many', 1)
#
# 'WGRU'
# ('spell', 4)
# ('each', 2)
# ('copy', 2)
# ('targets', 2)
# ('creatures', 1)
# ('one', 1)
# ('different', 1)
# ('target', 1)
# ('could', 1)
# ('other', 1)
#
# 'WBGU'
# ('nephilim', 2)
# ('witch-maw', 2)
# ('whenever', 2)
# ('greater', 1)
# ('10', 1)
# ('is', 1)
# ('power', 1)
# ('end', 1)
# ('trample', 1)
# ('gains', 1)
#
# 'WBRU'
# ('attacking', 1)
# ('tapped', 1)
# ('battlefield', 1)
# ('graveyard', 1)
# ('from', 1)
# ('card', 1)
# ('target', 1)
# ('return', 1)
# ('attacks', 1)
# ('nephilim', 1)
#
# {'B': {'# of cards: ': 2484,
#        'CMC': {'Max CMC': 11,
#                'Mean CMC': 3.4269572235673929,
#                'Median CMC': 3,
#                'Min CMC': 0},
#        'Power': {'Max Power': 13,
#                  'Mean Power': 2.531024531024531,
#                  'Median Power': 2,
#                  'Min Power': 0},
#        'Toughness': {'Max Toughness': 13,
#                      'Mean Toughness': 2.4675324675324677,
#                      'Median Toughness': 2,
#                      'Min Toughness': 0}},
#  'BG': {'# of cards: ': 99,
#         'CMC': {'Max CMC': 12,
#                 'Mean CMC': 3.8585858585858586,
#                 'Median CMC': 4,
#                 'Min CMC': 1},
#         'Power': {'Max Power': 10,
#                   'Mean Power': 3.25,
#                   'Median Power': 3,
#                   'Min Power': 1},
#         'Toughness': {'Max Toughness': 10,
#                       'Mean Toughness': 3.2666666666666666,
#                       'Median Toughness': 3,
#                       'Min Toughness': 1}},
#  'BGR': {'# of cards: ': 29,
#          'CMC': {'Max CMC': 8,
#                  'Mean CMC': 4.6896551724137927,
#                  'Median CMC': 5,
#                  'Min CMC': 2},
#          'Power': {'Max Power': 8,
#                    'Mean Power': 4.0999999999999996,
#                    'Median Power': 4,
#                    'Min Power': 1},
#          'Toughness': {'Max Toughness': 8,
#                        'Mean Toughness': 4.0,
#                        'Median Toughness': 4,
#                        'Min Toughness': 1}},
#  'BGRU': {'# of cards: ': 1,
#           'CMC': {'Max CMC': 4, 'Mean CMC': 4.0, 'Median CMC': 4, 'Min CMC': 4},
#           'Power': {'Max Power': 2,
#                     'Mean Power': 2.0,
#                     'Median Power': 2,
#                     'Min Power': 2},
#           'Toughness': {'Max Toughness': 2,
#                         'Mean Toughness': 2.0,
#                         'Median Toughness': 2,
#                         'Min Toughness': 2}},
#  'BGU': {'# of cards: ': 13,
#          'CMC': {'Max CMC': 7,
#                  'Mean CMC': 4.8461538461538458,
#                  'Median CMC': 5,
#                  'Min CMC': 3},
#          'Power': {'Max Power': 6,
#                    'Mean Power': 3.5,
#                    'Median Power': 4,
#                    'Min Power': 0},
#          'Toughness': {'Max Toughness': 6,
#                        'Mean Toughness': 3.7000000000000002,
#                        'Median Toughness': 4,
#                        'Min Toughness': 0}},
#  'BR': {'# of cards: ': 153,
#         'CMC': {'Max CMC': 8,
#                 'Mean CMC': 3.9215686274509802,
#                 'Median CMC': 4,
#                 'Min CMC': 1},
#         'Power': {'Max Power': 9,
#                   'Mean Power': 3.268041237113402,
#                   'Median Power': 3,
#                   'Min Power': 0},
#         'Toughness': {'Max Toughness': 9,
#                       'Mean Toughness': 2.8453608247422681,
#                       'Median Toughness': 3,
#                       'Min Toughness': 0}},
#  'BRU': {'# of cards: ': 31,
#          'CMC': {'Max CMC': 8,
#                  'Mean CMC': 4.806451612903226,
#                  'Median CMC': 4,
#                  'Min CMC': 2},
#          'Power': {'Max Power': 10,
#                    'Mean Power': 4.2857142857142856,
#                    'Median Power': 4,
#                    'Min Power': 1},
#          'Toughness': {'Max Toughness': 7,
#                        'Mean Toughness': 4.0,
#                        'Median Toughness': 4,
#                        'Min Toughness': 1}},
#  'BU': {'# of cards: ': 156,
#         'CMC': {'Max CMC': 8,
#                 'Mean CMC': 3.6602564102564101,
#                 'Median CMC': 4,
#                 'Min CMC': 1},
#         'Power': {'Max Power': 6,
#                   'Mean Power': 2.6373626373626373,
#                   'Median Power': 2,
#                   'Min Power': 0},
#         'Toughness': {'Max Toughness': 8,
#                       'Mean Toughness': 2.9890109890109891,
#                       'Median Toughness': 3,
#                       'Min Toughness': 0}},
#  'Colorless': {'# of cards: ': 2564,
#                'CMC': {'Max CMC': 16,
#                        'Mean CMC': 3.3470105509964831,
#                        'Median CMC': 3,
#                        'Min CMC': 0},
#                'Power': {'Max Power': 15,
#                          'Mean Power': 2.9098497495826376,
#                          'Median Power': 2,
#                          'Min Power': -1},
#                'Toughness': {'Max Toughness': 15,
#                              'Mean Toughness': 3.2437395659432386,
#                              'Median Toughness': 3,
#                              'Min Toughness': -1}},
#  'G': {'# of cards: ': 2493,
#        'CMC': {'Max CMC': 11,
#                'Mean CMC': 3.389469453376206,
#                'Median CMC': 3,
#                'Min CMC': 0},
#        'Power': {'Max Power': 15,
#                  'Mean Power': 2.700399467376831,
#                  'Median Power': 2,
#                  'Min Power': 0},
#        'Toughness': {'Max Toughness': 15,
#                      'Mean Toughness': 2.8235685752330228,
#                      'Median Toughness': 2,
#                      'Min Toughness': 0}},
#  'GR': {'# of cards: ': 155,
#         'CMC': {'Max CMC': 8,
#                 'Mean CMC': 3.8766233766233764,
#                 'Median CMC': 4,
#                 'Min CMC': 1},
#         'Power': {'Max Power': 8,
#                   'Mean Power': 3.4653465346534653,
#                   'Median Power': 3,
#                   'Min Power': 0},
#         'Toughness': {'Max Toughness': 8,
#                       'Mean Toughness': 3.2673267326732671,
#                       'Median Toughness': 3,
#                       'Min Toughness': 0}},
#  'GRU': {'# of cards: ': 14,
#          'CMC': {'Max CMC': 8, 'Mean CMC': 4.5, 'Median CMC': 5, 'Min CMC': 3},
#          'Power': {'Max Power': 7,
#                    'Mean Power': 4.333333333333333,
#                    'Median Power': 5,
#                    'Min Power': 1},
#          'Toughness': {'Max Toughness': 6,
#                        'Mean Toughness': 3.8888888888888888,
#                        'Median Toughness': 4,
#                        'Min Toughness': 1}},
#  'GU': {'# of cards: ': 98,
#         'CMC': {'Max CMC': 8,
#                 'Mean CMC': 3.6326530612244898,
#                 'Median CMC': 3,
#                 'Min CMC': 1},
#         'Power': {'Max Power': 6,
#                   'Mean Power': 2.171875,
#                   'Median Power': 2,
#                   'Min Power': 0},
#         'Toughness': {'Max Toughness': 7,
#                       'Mean Toughness': 2.484375,
#                       'Median Toughness': 2,
#                       'Min Toughness': 0}},
#  'R': {'# of cards: ': 2487,
#        'CMC': {'Max CMC': 10,
#                'Mean CMC': 3.3544099879178413,
#                'Median CMC': 3,
#                'Min CMC': 0},
#        'Power': {'Max Power': 10,
#                  'Mean Power': 2.6466763005780347,
#                  'Median Power': 2,
#                  'Min Power': -1},
#        'Toughness': {'Max Toughness': 10,
#                      'Mean Toughness': 2.4725433526011562,
#                      'Median Toughness': 2,
#                      'Min Toughness': 0}},
#  'RU': {'# of cards: ': 99,
#         'CMC': {'Max CMC': 7,
#                 'Mean CMC': 3.5656565656565657,
#                 'Median CMC': 3,
#                 'Min CMC': 1},
#         'Power': {'Max Power': 6,
#                   'Mean Power': 2.3157894736842106,
#                   'Median Power': 2,
#                   'Min Power': 0},
#         'Toughness': {'Max Toughness': 6,
#                       'Mean Toughness': 2.9298245614035086,
#                       'Median Toughness': 3,
#                       'Min Toughness': 0}},
#  'U': {'# of cards: ': 2456,
#        'CMC': {'Max CMC': 14,
#                'Mean CMC': 3.3621533442088092,
#                'Median CMC': 3,
#                'Min CMC': 0},
#        'Power': {'Max Power': 13,
#                  'Mean Power': 2.2185748598879105,
#                  'Median Power': 2,
#                  'Min Power': 0},
#        'Toughness': {'Max Toughness': 13,
#                      'Mean Toughness': 2.6693354683746997,
#                      'Median Toughness': 2,
#                      'Min Toughness': 0}},
#  'W': {'# of cards: ': 2504,
#        'CMC': {'Max CMC': 10,
#                'Mean CMC': 3.1502197363164202,
#                'Median CMC': 3,
#                'Min CMC': 0},
#        'Power': {'Max Power': 8,
#                  'Mean Power': 2.0436312456016887,
#                  'Median Power': 2,
#                  'Min Power': 0},
#        'Toughness': {'Max Toughness': 10,
#                      'Mean Toughness': 2.5566502463054186,
#                      'Median Toughness': 2,
#                      'Min Toughness': 0}},
#  'WB': {'# of cards: ': 104,
#         'CMC': {'Max CMC': 8,
#                 'Mean CMC': 3.6153846153846154,
#                 'Median CMC': 3,
#                 'Min CMC': 1},
#         'Power': {'Max Power': 6,
#                   'Mean Power': 2.6896551724137931,
#                   'Median Power': 2,
#                   'Min Power': 0},
#         'Toughness': {'Max Toughness': 6,
#                       'Mean Toughness': 2.8793103448275863,
#                       'Median Toughness': 3,
#                       'Min Toughness': 1}},
#  'WBG': {'# of cards: ': 13,
#          'CMC': {'Max CMC': 8,
#                  'Mean CMC': 4.6923076923076925,
#                  'Median CMC': 5,
#                  'Min CMC': 3},
#          'Power': {'Max Power': 6,
#                    'Mean Power': 3.3333333333333335,
#                    'Median Power': 4,
#                    'Min Power': 0},
#          'Toughness': {'Max Toughness': 7,
#                        'Mean Toughness': 4.333333333333333,
#                        'Median Toughness': 4,
#                        'Min Toughness': 0}},
#  'WBGR': {'# of cards: ': 1,
#           'CMC': {'Max CMC': 4, 'Mean CMC': 4.0, 'Median CMC': 4, 'Min CMC': 4},
#           'Power': {'Max Power': 3,
#                     'Mean Power': 3.0,
#                     'Median Power': 3,
#                     'Min Power': 3},
#           'Toughness': {'Max Toughness': 3,
#                         'Mean Toughness': 3.0,
#                         'Median Toughness': 3,
#                         'Min Toughness': 3}},
#  'WBGRU': {'# of cards: ': 22,
#            'CMC': {'Max CMC': 10,
#                    'Mean CMC': 5.7272727272727275,
#                    'Median CMC': 5,
#                    'Min CMC': 4},
#            'Power': {'Max Power': 10,
#                      'Mean Power': 5.75,
#                      'Median Power': 5,
#                      'Min Power': 3},
#            'Toughness': {'Max Toughness': 10,
#                          'Mean Toughness': 5.75,
#                          'Median Toughness': 5,
#                          'Min Toughness': 3}},
#  'WBGU': {'# of cards: ': 1,
#           'CMC': {'Max CMC': 4, 'Mean CMC': 4.0, 'Median CMC': 4, 'Min CMC': 4},
#           'Power': {'Max Power': 1,
#                     'Mean Power': 1.0,
#                     'Median Power': 1,
#                     'Min Power': 1},
#           'Toughness': {'Max Toughness': 1,
#                         'Mean Toughness': 1.0,
#                         'Median Toughness': 1,
#                         'Min Toughness': 1}},
#  'WBR': {'# of cards: ': 13,
#          'CMC': {'Max CMC': 7,
#                  'Mean CMC': 4.5384615384615383,
#                  'Median CMC': 4,
#                  'Min CMC': 3},
#          'Power': {'Max Power': 7,
#                    'Mean Power': 4.0,
#                    'Median Power': 4,
#                    'Min Power': 2},
#          'Toughness': {'Max Toughness': 7,
#                        'Mean Toughness': 3.5555555555555554,
#                        'Median Toughness': 3,
#                        'Min Toughness': 2}},
#  'WBRU': {'# of cards: ': 1,
#           'CMC': {'Max CMC': 4, 'Mean CMC': 4.0, 'Median CMC': 4, 'Min CMC': 4},
#           'Power': {'Max Power': 2,
#                     'Mean Power': 2.0,
#                     'Median Power': 2,
#                     'Min Power': 2},
#           'Toughness': {'Max Toughness': 2,
#                         'Mean Toughness': 2.0,
#                         'Median Toughness': 2,
#                         'Min Toughness': 2}},
#  'WBU': {'# of cards: ': 29,
#          'CMC': {'Max CMC': 8,
#                  'Mean CMC': 4.6551724137931032,
#                  'Median CMC': 4,
#                  'Min CMC': 2},
#          'Power': {'Max Power': 7,
#                    'Mean Power': 3.3181818181818183,
#                    'Median Power': 3,
#                    'Min Power': 0},
#          'Toughness': {'Max Toughness': 7,
#                        'Mean Toughness': 3.6818181818181817,
#                        'Median Toughness': 4,
#                        'Min Toughness': 1}},
#  'WG': {'# of cards: ': 159,
#         'CMC': {'Max CMC': 15,
#                 'Mean CMC': 3.8176100628930816,
#                 'Median CMC': 3,
#                 'Min CMC': 1},
#         'Power': {'Max Power': 9,
#                   'Mean Power': 3.0480769230769229,
#                   'Median Power': 3,
#                   'Min Power': 0},
#         'Toughness': {'Max Toughness': 14,
#                       'Mean Toughness': 3.6057692307692308,
#                       'Median Toughness': 3,
#                       'Min Toughness': 0}},
#  'WGR': {'# of cards: ': 29,
#          'CMC': {'Max CMC': 8,
#                  'Mean CMC': 4.3793103448275863,
#                  'Median CMC': 4,
#                  'Min CMC': 2},
#          'Power': {'Max Power': 8,
#                    'Mean Power': 3.7727272727272729,
#                    'Median Power': 4,
#                    'Min Power': 0},
#          'Toughness': {'Max Toughness': 8,
#                        'Mean Toughness': 3.6363636363636362,
#                        'Median Toughness': 4,
#                        'Min Toughness': 0}},
#  'WGRU': {'# of cards: ': 1,
#           'CMC': {'Max CMC': 4, 'Mean CMC': 4.0, 'Median CMC': 4, 'Min CMC': 4},
#           'Power': {'Max Power': 3,
#                     'Mean Power': 3.0,
#                     'Median Power': 3,
#                     'Min Power': 3},
#           'Toughness': {'Max Toughness': 3,
#                         'Mean Toughness': 3.0,
#                         'Median Toughness': 3,
#                         'Min Toughness': 3}},
#  'WGU': {'# of cards: ': 30,
#          'CMC': {'Max CMC': 8,
#                  'Mean CMC': 4.2666666666666666,
#                  'Median CMC': 4,
#                  'Min CMC': 2},
#          'Power': {'Max Power': 7,
#                    'Mean Power': 3.1363636363636362,
#                    'Median Power': 3,
#                    'Min Power': 2},
#          'Toughness': {'Max Toughness': 8,
#                        'Mean Toughness': 3.5909090909090908,
#                        'Median Toughness': 3,
#                        'Min Toughness': 1}},
#  'WR': {'# of cards: ': 101,
#         'CMC': {'Max CMC': 8,
#                 'Mean CMC': 3.4851485148514851,
#                 'Median CMC': 3,
#                 'Min CMC': 1},
#         'Power': {'Max Power': 7,
#                   'Mean Power': 2.901639344262295,
#                   'Median Power': 3,
#                   'Min Power': 1},
#         'Toughness': {'Max Toughness': 6,
#                       'Mean Toughness': 2.6721311475409837,
#                       'Median Toughness': 2,
#                       'Min Toughness': 1}},
#  'WRU': {'# of cards: ': 12,
#          'CMC': {'Max CMC': 6,
#                  'Mean CMC': 4.583333333333333,
#                  'Median CMC': 5,
#                  'Min CMC': 3},
#          'Power': {'Max Power': 7,
#                    'Mean Power': 3.7777777777777777,
#                    'Median Power': 3,
#                    'Min Power': 2},
#          'Toughness': {'Max Toughness': 7,
#                        'Mean Toughness': 4.0,
#                        'Median Toughness': 4,
#                        'Min Toughness': 2}},
#  'WU': {'# of cards: ': 156,
#         'CMC': {'Max CMC': 8,
#                 'Mean CMC': 3.7884615384615383,
#                 'Median CMC': 4,
#                 'Min CMC': 1},
#         'Power': {'Max Power': 6,
#                   'Mean Power': 2.5729166666666665,
#                   'Median Power': 2,
#                   'Min Power': 0},
#         'Toughness': {'Max Toughness': 8,
#                       'Mean Toughness': 2.96875,
#                       'Median Toughness': 3,
#                       'Min Toughness': 1}}}

# %% [markdown]
# Analizando el ejemplo particular de las palabras mas usadas en el color Black Blue:
#
# ('their', 121)
#
# ('card', 117)
#
# ('player', 91)
#
# ('target', 87)
#
# ('cards', 70)
#
# ('library', 58)
#
# ('hand', 51)
#
# ('graveyard', 47)
#
# ('from', 42)
#
# ('top', 40)
#
#
# Esto concuerda con el arquetipo general de los decks de este color, en el que descartan cartas ('cards','hand', 'graveyard'), tiran cartas del tope del deck al cementerio ('cards','from','top','library','graveyard') y el control sobre las cartas del oponente ('target','their','player','cards')

# %%
#pprint.pprint(raw['10E']['cards'][0])
for i in range(len(raw['SOI']['cards'])):
    pprint.pprint("Name: " + raw['SOI']['cards'][i]['name'])
    if(raw['SOI']['cards'][i].get('text') is not None):
        pprint.pprint("Text: " + raw['SOI']['cards'][i]['text'])
    if(raw['SOI']['cards'][i].get('power') is not None):
        pprint.pprint("Power: " + raw['SOI']['cards'][i]['power'])
    if(raw['SOI']['cards'][i].get('toughness') is not None):
        pprint.pprint("Toughness: " + raw['SOI']['cards'][i]['toughness'])
    
    if(raw['SOI']['cards'][i].get('types') is not None):
        print('Types:')
        for x in raw['SOI']['cards'][i]['types']:
            
            print("   '" + x + "' ")
    if(raw['SOI']['cards'][i].get('subtypes') is not None):
        print('Subtypes:')
        for x in raw['SOI']['cards'][i]['subtypes']:
            
            print("   '" + x + "' ")
    print()
    #if (not raw['pWOS']['cards'][i]['text']== raw['pWOS']['cards'][i]['originalText']):
    #    pprint.pprint("Text: " + raw['pWOS']['cards'][i]['originalText'])
    #pprint.pprint(raw['10E']['cards'][i]['name'])
# Out:
# 'Name: Always Watching'
# 'Text: Nontoken creatures you control get +1/+1 and have vigilance.'
# Types:
#    'Enchantment'
#
# 'Name: Angel of Deliverance'
# ('Text: Flying\n'
#  'Delirium â€” Whenever Angel of Deliverance deals damage, if there are four '
#  'or more card types among cards in your graveyard, exile target creature an '
#  'opponent controls.')
# 'Power: 6'
# 'Toughness: 6'
# Types:
#    'Creature'
# Subtypes:
#    'Angel'
#
# 'Name: Angelic Purge'
# ('Text: As an additional cost to cast Angelic Purge, sacrifice a permanent.\n'
#  'Exile target artifact, creature, or enchantment.')
# Types:
#    'Sorcery'
#
# 'Name: Apothecary Geist'
# ('Text: Flying\n'
#  'When Apothecary Geist enters the battlefield, if you control another Spirit, '
#  'you gain 3 life.')
# 'Power: 2'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Spirit'
#
# 'Name: Archangel Avacyn'
# ('Text: Flash\n'
#  'Flying, vigilance\n'
#  'When Archangel Avacyn enters the battlefield, creatures you control gain '
#  'indestructible until end of turn.\n'
#  'When a non-Angel creature you control dies, transform Archangel Avacyn at '
#  'the beginning of the next upkeep.')
# 'Power: 4'
# 'Toughness: 4'
# Types:
#    'Creature'
# Subtypes:
#    'Angel'
#
# 'Name: Avacyn, the Purifier'
# ('Text: Flying\n'
#  'When this creature transforms into Avacyn, the Purifier, it deals 3 damage '
#  'to each other creature and each opponent.')
# 'Power: 6'
# 'Toughness: 5'
# Types:
#    'Creature'
# Subtypes:
#    'Angel'
#
# 'Name: Avacynian Missionaries'
# ('Text: At the beginning of your end step, if Avacynian Missionaries is '
#  'equipped, transform it.')
# 'Power: 3'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Cleric'
#
# 'Name: Lunarch Inquisitors'
# ('Text: When this creature transforms into Lunarch Inquisitors, you may exile '
#  'another target creature until Lunarch Inquisitors leaves the battlefield.')
# 'Power: 4'
# 'Toughness: 4'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Cleric'
#
# 'Name: Bound by Moonsilver'
# ('Text: Enchant creature\n'
#  "Enchanted creature can't attack, block, or transform.\n"
#  'Sacrifice another permanent: Attach Bound by Moonsilver to target creature. '
#  'Activate this ability only any time you could cast a sorcery and only once '
#  'each turn.')
# Types:
#    'Enchantment'
# Subtypes:
#    'Aura'
#
# 'Name: Bygone Bishop'
# ('Text: Flying\n'
#  'Whenever you cast a creature spell with converted mana cost 3 or less, '
#  'investigate. (Put a colorless Clue artifact token onto the battlefield with '
#  '"{2}, Sacrifice this artifact: Draw a card.")')
# 'Power: 2'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Spirit'
#    'Cleric'
#
# "Name: Cathar's Companion"
# ("Text: Whenever you cast a noncreature spell, Cathar's Companion gains "
#  'indestructible until end of turn. (Damage and effects that say "destroy" '
#  "don't destroy it.)")
# 'Power: 3'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Hound'
#
# "Name: Chaplain's Blessing"
# 'Text: You gain 5 life.'
# Types:
#    'Sorcery'
#
# 'Name: Dauntless Cathar'
# ('Text: {1}{W}, Exile Dauntless Cathar from your graveyard: Put a 1/1 white '
#  'Spirit creature token with flying onto the battlefield. Activate this '
#  'ability only any time you could cast a sorcery.')
# 'Power: 3'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Soldier'
#
# 'Name: Declaration in Stone'
# ('Text: Exile target creature and all other creatures its controller controls '
#  'with the same name as that creature. That player investigates for each '
#  'nontoken creature exiled this way.')
# Types:
#    'Sorcery'
#
# 'Name: Descend upon the Sinful'
# ('Text: Exile all creatures.\n'
#  'Delirium â€” Put a 4/4 white Angel creature token with flying onto the '
#  'battlefield if there are four or more card types among cards in your '
#  'graveyard.')
# Types:
#    'Sorcery'
#
# 'Name: Devilthorn Fox'
# 'Power: 3'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Fox'
#
# 'Name: Drogskol Cavalry'
# ('Text: Flying\n'
#  'Whenever another Spirit enters the battlefield under your control, you gain '
#  '2 life.\n'
#  '{3}{W}: Put a 1/1 white Spirit creature token with flying onto the '
#  'battlefield.')
# 'Power: 4'
# 'Toughness: 4'
# Types:
#    'Creature'
# Subtypes:
#    'Spirit'
#    'Knight'
#
# 'Name: Eerie Interlude'
# ('Text: Exile any number of target creatures you control. Return those cards '
#  "to the battlefield under their owner's control at the beginning of the next "
#  'end step.')
# Types:
#    'Instant'
#
# 'Name: Emissary of the Sleepless'
# ('Text: Flying\n'
#  'When Emissary of the Sleepless enters the battlefield, if a creature died '
#  'this turn, put a 1/1 white Spirit creature token with flying onto the '
#  'battlefield.')
# 'Power: 2'
# 'Toughness: 4'
# Types:
#    'Creature'
# Subtypes:
#    'Spirit'
#
# 'Name: Ethereal Guidance'
# 'Text: Creatures you control get +2/+1 until end of turn.'
# Types:
#    'Sorcery'
#
# 'Name: Expose Evil'
# ('Text: Tap up to two target creatures.\n'
#  'Investigate. (Put a colorless Clue artifact token onto the battlefield with '
#  '"{2}, Sacrifice this artifact: Draw a card.")')
# Types:
#    'Instant'
#
# "Name: Gryff's Boon"
# ('Text: Enchant creature\n'
#  'Enchanted creature gets +1/+0 and has flying.\n'
#  "{3}{W}: Return Gryff's Boon from your graveyard to the battlefield attached "
#  'to target creature. Activate this ability only any time you could cast a '
#  'sorcery.')
# Types:
#    'Enchantment'
# Subtypes:
#    'Aura'
#
# 'Name: Hanweir Militia Captain'
# ('Text: At the beginning of your upkeep, if you control four or more '
#  'creatures, transform Hanweir Militia Captain.')
# 'Power: 2'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Soldier'
#
# 'Name: Westvale Cult Leader'
# ("Text: Westvale Cult Leader's power and toughness are each equal to the "
#  'number of creatures you control.\n'
#  'At the beginning of your end step, put a 1/1 white and black Human Cleric '
#  'creature token onto the battlefield.')
# 'Power: *'
# 'Toughness: *'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Cleric'
#
# 'Name: Hope Against Hope'
# ('Text: Enchant creature\n'
#  'Enchanted creature gets +1/+1 for each creature you control.\n'
#  'As long as enchanted creature is a Human, it has first strike.')
# Types:
#    'Enchantment'
# Subtypes:
#    'Aura'
#
# 'Name: Humble the Brute'
# ('Text: Destroy target creature with power 4 or greater.\n'
#  'Investigate. (Put a colorless Clue artifact token onto the battlefield with '
#  '"{2}, Sacrifice this artifact: Draw a card.")')
# Types:
#    'Instant'
#
# "Name: Inquisitor's Ox"
# ("Text: Delirium â€” Inquisitor's Ox gets +1/+0 and has vigilance as long as "
#  'there are four or more card types among cards in your graveyard.')
# 'Power: 2'
# 'Toughness: 5'
# Types:
#    'Creature'
# Subtypes:
#    'Ox'
#
# 'Name: Inspiring Captain'
# ('Text: When Inspiring Captain enters the battlefield, creatures you control '
#  'get +1/+1 until end of turn.')
# 'Power: 3'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Knight'
#
# 'Name: Militant Inquisitor'
# 'Text: Militant Inquisitor gets +1/+0 for each Equipment you control.'
# 'Power: 2'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Cleric'
#
# 'Name: Moorland Drifter'
# ('Text: Delirium â€” Moorland Drifter has flying as long as there are four or '
#  'more card types among cards in your graveyard.')
# 'Power: 2'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Spirit'
#
# "Name: Nahiri's Machinations"
# ('Text: At the beginning of combat on your turn, target creature you control '
#  'gains indestructible until end of turn.\n'
#  "{1}{R}: Nahiri's Machinations deals 1 damage to target blocking creature.")
# Types:
#    'Enchantment'
#
# 'Name: Nearheath Chaplain'
# ('Text: Lifelink\n'
#  '{2}{W}, Exile Nearheath Chaplain from your graveyard: Put two 1/1 white '
#  'Spirit creature tokens with flying onto the battlefield. Activate this '
#  'ability only any time you could cast a sorcery.')
# 'Power: 3'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Cleric'
#
# 'Name: Not Forgotten'
# ("Text: Put target card from a graveyard on the top or bottom of its owner's "
#  'library. Put a 1/1 white Spirit creature token with flying onto the '
#  'battlefield.')
# Types:
#    'Sorcery'
#
# 'Name: Odric, Lunarch Marshal'
# ('Text: At the beginning of each combat, creatures you control gain first '
#  'strike until end of turn if a creature you control has first strike. The '
#  'same is true for flying, deathtouch, double strike, haste, hexproof, '
#  'indestructible, lifelink, menace, reach, skulk, trample, and vigilance.')
# 'Power: 3'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Soldier'
#
# 'Name: Open the Armory'
# ('Text: Search your library for an Aura or Equipment card, reveal it, and put '
#  'it into your hand. Then shuffle your library.')
# Types:
#    'Sorcery'
#
# 'Name: Paranoid Parish-Blade'
# ('Text: Delirium â€” Paranoid Parish-Blade gets +1/+0 and has first strike as '
#  'long as there are four or more card types among cards in your graveyard.')
# 'Power: 3'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Soldier'
#
# 'Name: Pious Evangel'
# ('Text: Whenever Pious Evangel or another creature enters the battlefield '
#  'under your control, you gain 1 life.\n'
#  '{2}, {T}, Sacrifice another permanent: Transform Pious Evangel.')
# 'Power: 2'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Cleric'
#
# 'Name: Wayward Disciple'
# ('Text: Whenever Wayward Disciple or another creature you control dies, target '
#  'opponent loses 1 life and you gain 1 life.')
# 'Power: 2'
# 'Toughness: 4'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Cleric'
#
# 'Name: Puncturing Light'
# 'Text: Destroy target attacking or blocking creature with power 3 or less.'
# Types:
#    'Instant'
#
# 'Name: Reaper of Flight Moonsilver'
# ('Text: Flying\n'
#  'Delirium â€” Sacrifice another creature: Reaper of Flight Moonsilver gets '
#  '+2/+1 until end of turn. Activate this ability only if there are four or '
#  'more card types among cards in your graveyard.')
# 'Power: 3'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Angel'
#
# 'Name: Silverstrike'
# 'Text: Destroy target attacking creature. You gain 3 life.'
# Types:
#    'Instant'
#
# 'Name: Spectral Shepherd'
# "Text: Flying\n{1}{U}: Return target Spirit you control to its owner's hand."
# 'Power: 2'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Spirit'
#
# 'Name: Stern Constable'
# 'Text: {T}, Discard a card: Tap target creature.'
# 'Power: 1'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Soldier'
#
# 'Name: Strength of Arms'
# ('Text: Target creature gets +2/+2 until end of turn. If you control an '
#  'Equipment, put a 1/1 white Human Soldier creature token onto the '
#  'battlefield.')
# Types:
#    'Instant'
#
# 'Name: Survive the Night'
# ('Text: Target creature gets +1/+0 and gains indestructible until end of turn. '
#  '(Damage and effects that say "destroy" don\'t destroy it.)\n'
#  'Investigate. (Put a colorless Clue artifact token onto the battlefield with '
#  '"{2}, Sacrifice this artifact: Draw a card.")')
# Types:
#    'Instant'
#
# 'Name: Tenacity'
# ('Text: Creatures you control get +1/+1 and gain lifelink until end of turn. '
#  'Untap those creatures.')
# Types:
#    'Instant'
#
# "Name: Thalia's Lieutenant"
# ("Text: When Thalia's Lieutenant enters the battlefield, put a +1/+1 counter "
#  'on each other Human you control.\n'
#  'Whenever another Human enters the battlefield under your control, put a '
#  "+1/+1 counter on Thalia's Lieutenant.")
# 'Power: 1'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Soldier'
#
# 'Name: Thraben Inspector'
# ('Text: When Thraben Inspector enters the battlefield, investigate. (Put a '
#  'colorless Clue artifact token onto the battlefield with "{2}, Sacrifice this '
#  'artifact: Draw a card.")')
# 'Power: 1'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Soldier'
#
# 'Name: Topplegeist'
# ('Text: Flying\n'
#  'When Topplegeist enters the battlefield, tap target creature an opponent '
#  'controls.\n'
#  "Delirium â€” At the beginning of each opponent's upkeep, if there are four "
#  'or more card types among cards in your graveyard, tap target creature that '
#  'player controls.')
# 'Power: 1'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Spirit'
#
# 'Name: Town Gossipmonger'
# 'Text: {T}, Tap an untapped creature you control: Transform Town Gossipmonger.'
# 'Power: 1'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#
# 'Name: Incited Rabble'
# ('Text: Incited Rabble attacks each combat if able.\n'
#  '{2}: Incited Rabble gets +1/+0 until end of turn.')
# 'Power: 2'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#
# 'Name: Unruly Mob'
# ('Text: Whenever another creature you control dies, put a +1/+1 counter on '
#  'Unruly Mob.')
# 'Power: 1'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#
# 'Name: Vessel of Ephemera'
# ('Text: {2}{W}, Sacrifice Vessel of Ephemera: Put two 1/1 white Spirit '
#  'creature tokens with flying onto the battlefield.')
# Types:
#    'Enchantment'
#
# 'Name: Aberrant Researcher'
# ('Text: Flying\n'
#  'At the beginning of your upkeep, put the top card of your library into your '
#  "graveyard. If it's an instant or sorcery card, transform Aberrant "
#  'Researcher.')
# 'Power: 3'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Insect'
#
# 'Name: Perfected Form'
# 'Text: Flying'
# 'Power: 5'
# 'Toughness: 4'
# Types:
#    'Creature'
# Subtypes:
#    'Insect'
#    'Horror'
#
# 'Name: Broken Concentration'
# ('Text: Counter target spell.\n'
#  'Madness {3}{U} (If you discard this card, discard it into exile. When you '
#  'do, cast it for its madness cost or put it into your graveyard.)')
# Types:
#    'Instant'
#
# 'Name: Catalog'
# 'Text: Draw two cards, then discard a card.'
# Types:
#    'Instant'
#
# 'Name: Compelling Deterrence'
# ("Text: Return target nonland permanent to its owner's hand. Then that player "
#  'discards a card if you control a Zombie.')
# Types:
#    'Instant'
#
# 'Name: Confirm Suspicions'
# ('Text: Counter target spell.\n'
#  'Investigate three times. (To investigate, put a colorless Clue artifact '
#  'token onto the battlefield with "{2}, Sacrifice this artifact: Draw a '
#  'card.")')
# Types:
#    'Instant'
#
# 'Name: Daring Sleuth'
# 'Text: When you sacrifice a Clue, transform Daring Sleuth.'
# 'Power: 2'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Rogue'
#
# 'Name: Bearer of Overwhelming Truths'
# ('Text: Prowess (Whenever you cast a noncreature spell, this creature gets '
#  '+1/+1 until end of turn.)\n'
#  'Whenever Bearer of Overwhelming Truths deals combat damage to a player, '
#  'investigate. (Put a colorless Clue artifact token onto the battlefield with '
#  '"{2}, Sacrifice this artifact: Draw a card.")')
# 'Power: 3'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Wizard'
#
# 'Name: Deny Existence'
# ('Text: Counter target creature spell. If that spell is countered this way, '
#  "exile it instead of putting it into its owner's graveyard.")
# Types:
#    'Instant'
#
# 'Name: Drownyard Explorers'
# ('Text: When Drownyard Explorers enters the battlefield, investigate. (Put a '
#  'colorless Clue artifact token onto the battlefield with "{2}, Sacrifice this '
#  'artifact: Draw a card.")')
# 'Power: 2'
# 'Toughness: 4'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Wizard'
#
# 'Name: Drunau Corpse Trawler'
# ('Text: When Drunau Corpse Trawler enters the battlefield, put a 2/2 black '
#  'Zombie creature token onto the battlefield.\n'
#  '{2}{B}: Target Zombie gains deathtouch until end of turn.')
# 'Power: 1'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Zombie'
#
# 'Name: Engulf the Shore'
# ("Text: Return to their owners' hands all creatures with toughness less than "
#  'or equal to the number of Islands you control.')
# Types:
#    'Instant'
#
# 'Name: Epiphany at the Drownyard'
# ('Text: Reveal the top X plus one cards of your library and separate them into '
#  'two piles. An opponent chooses one of those piles. Put that pile into your '
#  'hand and the other into your graveyard.')
# Types:
#    'Instant'
#
# 'Name: Erdwal Illuminator'
# ('Text: Flying\n'
#  'Whenever you investigate for the first time each turn, investigate an '
#  'additional time.')
# 'Power: 1'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Spirit'
#
# 'Name: Essence Flux'
# ('Text: Exile target creature you control, then return that card to the '
#  "battlefield under its owner's control. If it's a Spirit, put a +1/+1 counter "
#  'on it.')
# Types:
#    'Instant'
#
# 'Name: Fleeting Memories'
# ('Text: When Fleeting Memories enters the battlefield, investigate. (Put a '
#  'colorless Clue artifact token onto the battlefield with "{2}, Sacrifice this '
#  'artifact: Draw a card.")\n'
#  'Whenever you sacrifice a Clue, target player puts the top three cards of his '
#  'or her library into his or her graveyard.')
# Types:
#    'Enchantment'
#
# 'Name: Forgotten Creation'
# ("Text: Skulk (This creature can't be blocked by creatures with greater "
#  'power.)\n'
#  'At the beginning of your upkeep, you may discard all the cards in your hand. '
#  'If you do, draw that many cards.')
# 'Power: 3'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Zombie'
#    'Horror'
#
# 'Name: Furtive Homunculus'
# "Text: Skulk (This creature can't be blocked by creatures with greater power.)"
# 'Power: 2'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Homunculus'
#
# "Name: Geralf's Masterpiece"
# ('Text: Flying\n'
#  "Geralf's Masterpiece gets -1/-1 for each card in your hand.\n"
#  "{3}{U}, Discard three cards: Return Geralf's Masterpiece from your graveyard "
#  'to the battlefield tapped.')
# 'Power: 7'
# 'Toughness: 7'
# Types:
#    'Creature'
# Subtypes:
#    'Zombie'
#    'Horror'
#
# 'Name: Ghostly Wings'
# ('Text: Enchant creature\n'
#  'Enchanted creature gets +1/+1 and has flying.\n'
#  "Discard a card: Return enchanted creature to its owner's hand.")
# Types:
#    'Enchantment'
# Subtypes:
#    'Aura'
#
# 'Name: Gone Missing'
# ("Text: Put target permanent on top of its owner's library.\n"
#  'Investigate. (Put a colorless Clue artifact token onto the battlefield with '
#  '"{2}, Sacrifice this artifact: Draw a card.")')
# Types:
#    'Sorcery'
#
# 'Name: Invasive Surgery'
# ('Text: Counter target sorcery spell.\n'
#  'Delirium â€” If there are four or more card types among cards in your '
#  "graveyard, search the graveyard, hand, and library of that spell's "
#  'controller for any number of cards with the same name as that spell, exile '
#  'those cards, then that player shuffles his or her library.')
# Types:
#    'Instant'
#
# 'Name: Jace, Unraveler of Secrets'
# ('Text: +1: Scry 1, then draw a card.\n'
#  "âˆ’2: Return target creature to its owner's hand.\n"
#  'âˆ’8: You get an emblem with "Whenever an opponent casts his or her first '
#  'spell each turn, counter that spell."')
# Types:
#    'Planeswalker'
# Subtypes:
#    'Jace'
#
# "Name: Jace's Scrutiny"
# ('Text: Target creature gets -4/-0 until end of turn.\n'
#  'Investigate. (Put a colorless Clue artifact token onto the battlefield with '
#  '"{2}, Sacrifice this artifact: Draw a card.")')
# Types:
#    'Instant'
#
# 'Name: Just the Wind'
# ("Text: Return target creature to its owner's hand.\n"
#  'Madness {U} (If you discard this card, discard it into exile. When you do, '
#  'cast it for its madness cost or put it into your graveyard.)')
# Types:
#    'Instant'
#
# 'Name: Lamplighter of Selhoff'
# ('Text: When Lamplighter of Selhoff enters the battlefield, if you control '
#  'another Zombie, you may draw a card. If you do, discard a card.')
# 'Power: 3'
# 'Toughness: 5'
# Types:
#    'Creature'
# Subtypes:
#    'Zombie'
#    'Horror'
#
# 'Name: Manic Scribe'
# ('Text: When Manic Scribe enters the battlefield, each opponent puts the top '
#  'three cards of his or her library into his or her graveyard.\n'
#  "Delirium â€” At the beginning of each opponent's upkeep, if there are four "
#  'or more card types among cards in your graveyard, that player puts the top '
#  'three cards of his or her library into his or her graveyard.')
# 'Power: 0'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Wizard'
#
# 'Name: Nagging Thoughts'
# ('Text: Look at the top two cards of your library. Put one of them into your '
#  'hand and the other into your graveyard.\n'
#  'Madness {1}{U} (If you discard this card, discard it into exile. When you '
#  'do, cast it for its madness cost or put it into your graveyard.)')
# Types:
#    'Sorcery'
#
# 'Name: Nephalia Moondrakes'
# ('Text: Flying\n'
#  'When Nephalia Moondrakes enters the battlefield, target creature gains '
#  'flying until end of turn.\n'
#  '{4}{U}{U}, Exile Nephalia Moondrakes from your graveyard: Creatures you '
#  'control gain flying until end of turn.')
# 'Power: 5'
# 'Toughness: 5'
# Types:
#    'Creature'
# Subtypes:
#    'Drake'
#
# 'Name: Niblis of Dusk'
# ('Text: Flying\n'
#  'Prowess (Whenever you cast a noncreature spell, this creature gets +1/+1 '
#  'until end of turn.)')
# 'Power: 2'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Spirit'
#
# 'Name: Ongoing Investigation'
# ('Text: Whenever one or more creatures you control deal combat damage to a '
#  'player, investigate. (Put a colorless Clue artifact token onto the '
#  'battlefield with "{2}, Sacrifice this artifact: Draw a card.")\n'
#  '{1}{G}, Exile a creature card from your graveyard: Investigate. You gain 2 '
#  'life.')
# Types:
#    'Enchantment'
#
# 'Name: Pieces of the Puzzle'
# ('Text: Reveal the top five cards of your library. Put up to two instant '
#  'and/or sorcery cards from among them into your hand and the rest into your '
#  'graveyard.')
# Types:
#    'Sorcery'
#
# 'Name: Pore Over the Pages'
# 'Text: Draw three cards, untap up to two lands, then discard a card.'
# Types:
#    'Sorcery'
#
# 'Name: Press for Answers'
# ("Text: Tap target creature. It doesn't untap during its controller's next "
#  'untap step.\n'
#  'Investigate. (Put a colorless Clue artifact token onto the battlefield with '
#  '"{2}, Sacrifice this artifact: Draw a card.")')
# Types:
#    'Sorcery'
#
# 'Name: Rattlechains'
# ('Text: Flash\n'
#  'Flying\n'
#  'When Rattlechains enters the battlefield, target Spirit gains hexproof until '
#  'end of turn.\n'
#  'You may cast Spirit spells as though they had flash.')
# 'Power: 2'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Spirit'
#
# 'Name: Reckless Scholar'
# 'Text: {T}: Target player draws a card, then discards a card.'
# 'Power: 2'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Wizard'
#
# 'Name: Rise from the Tides'
# ('Text: Put a 2/2 black Zombie creature token onto the battlefield tapped for '
#  'each instant and sorcery card in your graveyard.')
# Types:
#    'Sorcery'
#
# 'Name: Seagraf Skaab'
# 'Power: 1'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Zombie'
#
# 'Name: Silburlind Snapper'
# ("Text: Silburlind Snapper can't attack unless you've cast a noncreature spell "
#  'this turn.')
# 'Power: 6'
# 'Toughness: 6'
# Types:
#    'Creature'
# Subtypes:
#    'Turtle'
#
# 'Name: Silent Observer'
# 'Text: Flying'
# 'Power: 1'
# 'Toughness: 5'
# Types:
#    'Creature'
# Subtypes:
#    'Spirit'
#
# 'Name: Sleep Paralysis'
# ('Text: Enchant creature\n'
#  'When Sleep Paralysis enters the battlefield, tap enchanted creature.\n'
#  "Enchanted creature doesn't untap during its controller's untap step.")
# Types:
#    'Enchantment'
# Subtypes:
#    'Aura'
#
# 'Name: Startled Awake'
# ('Text: Target opponent puts the top thirteen cards of his or her library into '
#  'his or her graveyard.\n'
#  '{3}{U}{U}: Put Startled Awake from your graveyard onto the battlefield '
#  'transformed. Activate this ability only any time you could cast a sorcery.')
# Types:
#    'Sorcery'
#
# 'Name: Persistent Nightmare'
# ("Text: Skulk (This creature can't be blocked by creatures with greater "
#  'power.)\n'
#  'When Persistent Nightmare deals combat damage to a player, return it to its '
#  "owner's hand.")
# 'Power: 1'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Nightmare'
#
# 'Name: Stitched Mangler'
# ('Text: Stitched Mangler enters the battlefield tapped.\n'
#  'When Stitched Mangler enters the battlefield, tap target creature an '
#  "opponent controls. That creature doesn't untap during its controller's next "
#  'untap step.')
# 'Power: 2'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Zombie'
#    'Horror'
#
# 'Name: Stitchwing Skaab'
# ('Text: Flying\n'
#  '{1}{U}, Discard two cards: Return Stitchwing Skaab from your graveyard to '
#  'the battlefield tapped.')
# 'Power: 3'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Zombie'
#    'Horror'
#
# 'Name: Stormrider Spirit'
# ('Text: Flash (You may cast this spell any time you could cast an instant.)\n'
#  'Flying')
# 'Power: 3'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Spirit'
#
# 'Name: Thing in the Ice'
# ('Text: Defender\n'
#  'Thing in the Ice enters the battlefield with four ice counters on it.\n'
#  'Whenever you cast an instant or sorcery spell, remove an ice counter from '
#  'Thing in the Ice. Then if it has no ice counters on it, transform it.')
# 'Power: 0'
# 'Toughness: 4'
# Types:
#    'Creature'
# Subtypes:
#    'Horror'
#
# 'Name: Awoken Horror'
# ('Text: When this creature transforms into Awoken Horror, return all '
#  "non-Horror creatures to their owners' hands.")
# 'Power: 7'
# 'Toughness: 8'
# Types:
#    'Creature'
# Subtypes:
#    'Kraken'
#    'Horror'
#
# 'Name: Trail of Evidence'
# ('Text: Whenever you cast an instant or sorcery spell, investigate. (Put a '
#  'colorless Clue artifact token onto the battlefield with "{2}, Sacrifice this '
#  'artifact: Draw a card.")')
# Types:
#    'Enchantment'
#
# 'Name: Uninvited Geist'
# ("Text: Skulk (This creature can't be blocked by creatures with greater "
#  'power.)\n'
#  'When Uninvited Geist deals combat damage to a player, transform it.')
# 'Power: 2'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Spirit'
#
# 'Name: Unimpeded Trespasser'
# "Text: Unimpeded Trespasser can't be blocked."
# 'Power: 3'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Spirit'
#
# 'Name: Vessel of Paramnesia'
# ('Text: {U}, Sacrifice Vessel of Paramnesia: Target player puts the top three '
#  'cards of his or her library into his or her graveyard. Draw a card.')
# Types:
#    'Enchantment'
#
# 'Name: Welcome to the Fold'
# ('Text: Madness {X}{U}{U} (If you discard this card, discard it into exile. '
#  'When you do, cast it for its madness cost or put it into your graveyard.)\n'
#  'Gain control of target creature if its toughness is 2 or less. If Welcome to '
#  "the Fold's madness cost was paid, instead gain control of that creature if "
#  'its toughness is X or less.')
# Types:
#    'Sorcery'
#
# 'Name: Accursed Witch'
# ('Text: Spells your opponents cast that target Accursed Witch cost {1} less to '
#  'cast.\n'
#  'When Accursed Witch dies, return it to the battlefield transformed under '
#  'your control attached to target opponent.')
# 'Power: 4'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Shaman'
#
# 'Name: Infectious Curse'
# ('Text: Enchant player\n'
#  'Spells you cast that target enchanted player cost {1} less to cast.\n'
#  "At the beginning of enchanted player's upkeep, that player loses 1 life and "
#  'you gain 1 life.')
# Types:
#    'Enchantment'
# Subtypes:
#    'Aura'
#    'Curse'
#
# 'Name: Alms of the Vein'
# ('Text: Target opponent loses 3 life and you gain 3 life. \n'
#  'Madness {B} (If you discard this card, discard it into exile. When you do, '
#  'cast it for its madness cost or put it into your graveyard.)')
# Types:
#    'Sorcery'
#
# 'Name: Asylum Visitor'
# ("Text: At the beginning of each player's upkeep, if that player has no cards "
#  'in hand, you draw a card and you lose 1 life.\n'
#  'Madness {1}{B} (If you discard this card, discard it into exile. When you '
#  'do, cast it for its madness cost or put it into your graveyard.)')
# 'Power: 3'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Vampire'
#    'Wizard'
#
# 'Name: Behind the Scenes'
# ("Text: Creatures you control have skulk. (They can't be blocked by creatures "
#  'with greater power.)\n'
#  '{4}{W}: Creatures you control get +1/+1 until end of turn.')
# Types:
#    'Enchantment'
#
# 'Name: Behold the Beyond'
# ('Text: Discard your hand. Search your library for three cards and put those '
#  'cards into your hand. Then shuffle your library.')
# Types:
#    'Sorcery'
#
# 'Name: Biting Rain'
# ('Text: All creatures get -2/-2 until end of turn. \n'
#  'Madness {2}{B} (If you discard this card, discard it into exile. When you '
#  'do, cast it for its madness cost or put it into your graveyard.)')
# Types:
#    'Sorcery'
#
# 'Name: Call the Bloodline'
# ('Text: {1}, Discard a card: Put a 1/1 black Vampire Knight creature token '
#  'with lifelink onto the battlefield. Activate this ability only once each '
#  'turn.')
# Types:
#    'Enchantment'
#
# 'Name: Creeping Dread'
# ('Text: At the beginning of your upkeep, each player discards a card. Each '
#  'opponent who discarded a card that shares a card type with the card you '
#  'discarded loses 3 life. (Players reveal the discarded cards simultaneously.)')
# Types:
#    'Enchantment'
#
# 'Name: Crow of Dark Tidings'
# ('Text: Flying\n'
#  'When Crow of Dark Tidings enters the battlefield or dies, put the top two '
#  'cards of your library into your graveyard.')
# 'Power: 2'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Zombie'
#    'Bird'
#
# 'Name: Dead Weight'
# 'Text: Enchant creature\nEnchanted creature gets -2/-2.'
# Types:
#    'Enchantment'
# Subtypes:
#    'Aura'
#
# 'Name: Diregraf Colossus'
# ('Text: Diregraf Colossus enters the battlefield with a +1/+1 counter on it '
#  'for each Zombie card in your graveyard.\n'
#  'Whenever you cast a Zombie spell, put a 2/2 black Zombie creature token onto '
#  'the battlefield tapped.')
# 'Power: 2'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Zombie'
#    'Giant'
#
# 'Name: Elusive Tormentor'
# 'Text: {1}, Discard a card: Transform Elusive Tormentor.'
# 'Power: 4'
# 'Toughness: 4'
# Types:
#    'Creature'
# Subtypes:
#    'Vampire'
#    'Wizard'
#
# 'Name: Insidious Mist'
# ('Text: Hexproof, indestructible\n'
#  "Insidious Mist can't block and can't be blocked.\n"
#  "Whenever Insidious Mist attacks and isn't blocked, you may pay {2}{B}. If "
#  'you do, transform it.')
# 'Power: 0'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Elemental'
#
# 'Name: Ever After'
# ('Text: Return up to two target creature cards from your graveyard to the '
#  'battlefield. Each of those creatures is a black Zombie in addition to its '
#  "other colors and types. Put Ever After on the bottom of its owner's library.")
# Types:
#    'Sorcery'
#
# 'Name: Farbog Revenant'
# ("Text: Skulk (This creature can't be blocked by creatures with greater "
#  'power.)\n'
#  'Lifelink (Damage dealt by this creature also causes you to gain that much '
#  'life.)')
# 'Power: 1'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Spirit'
#
# 'Name: From Under the Floorboards'
# ('Text: Madness {X}{B}{B} (If you discard this card, discard it into exile. '
#  'When you do, cast it for its madness cost or put it into your graveyard.)\n'
#  'Put three 2/2 black Zombie creature tokens onto the battlefield tapped and '
#  "you gain 3 life. If From Under the Floorboards's madness cost was paid, "
#  'instead put X of those tokens onto the battlefield tapped and you gain X '
#  'life.')
# Types:
#    'Sorcery'
#
# "Name: Ghoulcaller's Accomplice"
# ("Text: {3}{B}, Exile Ghoulcaller's Accomplice from your graveyard: Put a 2/2 "
#  'black Zombie creature token onto the battlefield. Activate this ability only '
#  'any time you could cast a sorcery.')
# 'Power: 2'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Rogue'
#
# 'Name: Ghoulsteed'
# ('Text: {2}{B}, Discard two cards: Return Ghoulsteed from your graveyard to '
#  'the battlefield tapped.')
# 'Power: 4'
# 'Toughness: 4'
# Types:
#    'Creature'
# Subtypes:
#    'Zombie'
#    'Horse'
#
# "Name: Gisa's Bidding"
# ('Text: Put two 2/2 black Zombie creature tokens onto the battlefield.\n'
#  'Madness {2}{B} (If you discard this card, discard it into exile. When you '
#  'do, cast it for its madness cost or put it into your graveyard.)')
# Types:
#    'Sorcery'
#
# 'Name: Grotesque Mutation'
# ('Text: Target creature gets +3/+1 and gains lifelink until end of turn. '
#  '(Damage dealt by the creature also causes its controller to gain that much '
#  'life.)')
# Types:
#    'Instant'
#
# 'Name: Heir of Falkenrath'
# ('Text: Discard a card: Transform Heir of Falkenrath. Activate this ability '
#  'only once each turn.')
# 'Power: 2'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Vampire'
#
# 'Name: Heir to the Night'
# 'Text: Flying'
# 'Power: 3'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Vampire'
#    'Berserker'
#
# 'Name: Hound of the Farbogs'
# ('Text: Delirium â€” Hound of the Farbogs has menace as long as there are four '
#  'or more card types among cards in your graveyard. (A creature with menace '
#  "can't be blocked except by two or more creatures.)")
# 'Power: 5'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Zombie'
#    'Hound'
#
# 'Name: Indulgent Aristocrat'
# ('Text: Lifelink\n'
#  '{2}, Sacrifice a creature: Put a +1/+1 counter on each Vampire you control.')
# 'Power: 1'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Vampire'
#
# 'Name: Kindly Stranger'
# ('Text: Delirium â€” {2}{B}: Transform Kindly Stranger. Activate this ability '
#  'only if there are four or more card types among cards in your graveyard.')
# 'Power: 2'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#
# 'Name: Demon-Possessed Witch'
# ('Text: When this creature transforms into Demon-Possessed Witch, you may '
#  'destroy target creature.')
# 'Power: 4'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Shaman'
#
# "Name: Liliana's Indignation"
# ('Text: Put the top X cards of your library into your graveyard. Target player '
#  'loses 2 life for each creature card put into your graveyard this way.')
# Types:
#    'Sorcery'
#
# 'Name: Macabre Waltz'
# ('Text: Return up to two target creature cards from your graveyard to your '
#  'hand, then discard a card.')
# Types:
#    'Sorcery'
#
# 'Name: Markov Dreadknight'
# ('Text: Flying\n'
#  '{2}{B}, Discard a card: Put two +1/+1 counters on Markov Dreadknight.')
# 'Power: 3'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Vampire'
#    'Knight'
#
# 'Name: Merciless Resolve'
# ('Text: As an additional cost to cast Merciless Resolve, sacrifice a creature '
#  'or land.\n'
#  'Draw two cards.')
# Types:
#    'Instant'
#
# 'Name: Mindwrack Demon'
# ('Text: Flying, trample\n'
#  'When Mindwrack Demon enters the battlefield, put the top four cards of your '
#  'library into your graveyard.\n'
#  'Delirium â€” At the beginning of your upkeep, you lose 4 life unless there '
#  'are four or more card types among cards in your graveyard.')
# 'Power: 4'
# 'Toughness: 5'
# Types:
#    'Creature'
# Subtypes:
#    'Demon'
#
# 'Name: Morkrut Necropod'
# ("Text: Menace (This creature can't be blocked except by two or more "
#  'creatures.)\n'
#  'Whenever Morkrut Necropod attacks or blocks, sacrifice another creature or '
#  'land.')
# 'Power: 7'
# 'Toughness: 7'
# Types:
#    'Creature'
# Subtypes:
#    'Slug'
#    'Horror'
#
# 'Name: Murderous Compulsion'
# ('Text: Destroy target tapped creature.\n'
#  'Madness {1}{B} (If you discard this card, discard it into exile. When you '
#  'do, cast it for its madness cost or put it into your graveyard.)')
# Types:
#    'Sorcery'
#
# "Name: Olivia's Bloodsworn"
# ('Text: Flying\n'
#  "Olivia's Bloodsworn can't block.\n"
#  '{R}: Target Vampire gains haste until end of turn.')
# 'Power: 2'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Vampire'
#    'Soldier'
#
# 'Name: Pale Rider of Trostad'
# ("Text: Skulk (This creature can't be blocked by creatures with greater "
#  'power.)\n'
#  'When Pale Rider of Trostad enters the battlefield, discard a card.')
# 'Power: 3'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Spirit'
#
# 'Name: Pick the Brain'
# ('Text: Target opponent reveals his or her hand. You choose a nonland card '
#  'from it and exile that card.\n'
#  'Delirium â€” If there are four or more card types among cards in your '
#  "graveyard, search that player's graveyard, hand, and library for any number "
#  'of cards with the same name as the exiled card, exile those cards, then that '
#  'player shuffles his or her library.')
# Types:
#    'Sorcery'
#
# 'Name: Rancid Rats'
# ("Text: Skulk (This creature can't be blocked by creatures with greater "
#  'power.)\n'
#  'Deathtouch (Any amount of damage this deals to a creature is enough to '
#  'destroy it.)')
# 'Power: 1'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Zombie'
#    'Rat'
#
# 'Name: Relentless Dead'
# ("Text: Menace (This creature can't be blocked except by two or more "
#  'creatures.)\n'
#  'When Relentless Dead dies, you may pay {B}. If you do, return it to its '
#  "owner's hand.\n"
#  'When Relentless Dead dies, you may pay {X}. If you do, return another target '
#  'Zombie creature card with converted mana cost X from your graveyard to the '
#  'battlefield.')
# 'Power: 2'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Zombie'
#
# 'Name: Rottenheart Ghoul'
# 'Text: When Rottenheart Ghoul dies, target player discards a card.'
# 'Power: 2'
# 'Toughness: 4'
# Types:
#    'Creature'
# Subtypes:
#    'Zombie'
#
# 'Name: Sanitarium Skeleton'
# 'Text: {2}{B}: Return Sanitarium Skeleton from your graveyard to your hand.'
# 'Power: 1'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Skeleton'
#
# 'Name: Shamble Back'
# ('Text: Exile target creature card from a graveyard. Put a 2/2 black Zombie '
#  'creature token onto the battlefield. You gain 2 life.')
# Types:
#    'Sorcery'
#
# 'Name: Sinister Concoction'
# ('Text: {B}, Pay 1 life, Put the top card of your library into your graveyard, '
#  'Discard a card, Sacrifice Sinister Concoction: Destroy target creature.')
# Types:
#    'Enchantment'
#
# 'Name: Stallion of Ashmouth'
# ('Text: Delirium â€” {1}{B}: Stallion of Ashmouth gets +1/+1 until end of '
#  'turn. Activate this ability only if there are four or more card types among '
#  'cards in your graveyard.')
# 'Power: 3'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Nightmare'
#    'Horse'
#
# 'Name: Stromkirk Mentor'
# ('Text: When Stromkirk Mentor enters the battlefield, put a +1/+1 counter on '
#  'another target Vampire you control.')
# 'Power: 4'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Vampire'
#    'Soldier'
#
# 'Name: Throttle'
# 'Text: Target creature gets -4/-4 until end of turn.'
# Types:
#    'Instant'
#
# 'Name: To the Slaughter'
# ('Text: Target player sacrifices a creature or planeswalker.\n'
#  'Delirium â€” If there are four or more card types among cards in your '
#  'graveyard, instead that player sacrifices a creature and a planeswalker.')
# Types:
#    'Instant'
#
# 'Name: Tooth Collector'
# ('Text: When Tooth Collector enters the battlefield, target creature an '
#  'opponent controls gets -1/-1 until end of turn.\n'
#  "Delirium â€” At the beginning of each opponent's upkeep, if there are four "
#  'or more card types among cards in your graveyard, target creature that '
#  'player controls gets -1/-1 until end of turn.')
# 'Power: 3'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Rogue'
#
# 'Name: Triskaidekaphobia'
# ('Text: At the beginning of your upkeep, choose one â€”\n'
#  'â€¢ Each player with exactly 13 life loses the game, then each player gains '
#  '1 life.\n'
#  'â€¢ Each player with exactly 13 life loses the game, then each player loses '
#  '1 life.')
# Types:
#    'Enchantment'
#
# 'Name: Twins of Maurer Estate'
# ('Text: Madness {2}{B} (If you discard this card, discard it into exile. When '
#  'you do, cast it for its madness cost or put it into your graveyard.)')
# 'Power: 3'
# 'Toughness: 5'
# Types:
#    'Creature'
# Subtypes:
#    'Vampire'
#
# 'Name: Vampire Noble'
# 'Power: 3'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Vampire'
#
# 'Name: Vessel of Malignity'
# ('Text: {1}{B}, Sacrifice Vessel of Malignity: Target opponent exiles two '
#  'cards from his or her hand. Activate this ability only any time you could '
#  'cast a sorcery.')
# Types:
#    'Enchantment'
#
# "Name: Avacyn's Judgment"
# ('Text: Madness {X}{R} (If you discard this card, discard it into exile. When '
#  'you do, cast it for its madness cost or put it into your graveyard.)\n'
#  "Avacyn's Judgment deals 2 damage divided as you choose among any number of "
#  "target creatures and/or players. If Avacyn's Judgment's madness cost was "
#  'paid, it deals X damage divided as you choose among those creatures and/or '
#  'players instead.')
# Types:
#    'Sorcery'
#
# 'Name: Bloodmad Vampire'
# ('Text: Whenever Bloodmad Vampire deals combat damage to a player, put a +1/+1 '
#  'counter on it.\n'
#  'Madness {1}{R} (If you discard this card, discard it into exile. When you '
#  'do, cast it for its madness cost or put it into your graveyard.)')
# 'Power: 4'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Vampire'
#    'Berserker'
#
# 'Name: Breakneck Rider'
# ('Text: At the beginning of each upkeep, if no spells were cast last turn, '
#  'transform Breakneck Rider.')
# 'Power: 3'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Scout'
#    'Werewolf'
#
# 'Name: Neck Breaker'
# ('Text: Attacking creatures you control get +1/+0 and have trample.\n'
#  'At the beginning of each upkeep, if a player cast two or more spells last '
#  'turn, transform Neck Breaker.')
# 'Power: 4'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Werewolf'
#
# 'Name: Burn from Within'
# ('Text: Burn from Within deals X damage to target creature or player. If a '
#  'creature is dealt damage this way, it loses indestructible until end of '
#  'turn. If that creature would die this turn, exile it instead.')
# Types:
#    'Sorcery'
#
# 'Name: Convicted Killer'
# ('Text: At the beginning of each upkeep, if no spells were cast last turn, '
#  'transform Convicted Killer.')
# 'Power: 2'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Werewolf'
#
# 'Name: Branded Howler'
# ('Text: At the beginning of each upkeep, if a player cast two or more spells '
#  'last turn, transform Branded Howler.')
# 'Power: 4'
# 'Toughness: 4'
# Types:
#    'Creature'
# Subtypes:
#    'Werewolf'
#
# 'Name: Dance with Devils'
# ('Text: Put two 1/1 red Devil creature tokens onto the battlefield. They have '
#  '"When this creature dies, it deals 1 damage to target creature or player."')
# Types:
#    'Instant'
#
# "Name: Devils' Playground"
# ('Text: Put four 1/1 red Devil creature tokens onto the battlefield. They have '
#  '"When this creature dies, it deals 1 damage to target creature or player."')
# Types:
#    'Sorcery'
#
# 'Name: Dissension in the Ranks'
# 'Text: Target blocking creature fights another target blocking creature.'
# Types:
#    'Instant'
#
# 'Name: Dual Shot'
# 'Text: Dual Shot deals 1 damage to each of up to two target creatures.'
# Types:
#    'Instant'
#
# 'Name: Ember-Eye Wolf'
# 'Text: Haste\n{1}{R}: Ember-Eye Wolf gets +2/+0 until end of turn.'
# 'Power: 1'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Wolf'
#
# 'Name: Falkenrath Gorger'
# ("Text: Each Vampire creature card you own that isn't on the battlefield has "
#  'madness. The madness cost is equal to its mana cost. (If you discard a card '
#  'with madness, discard it into exile. When you do, cast it for its madness '
#  'cost or put it into your graveyard.)')
# 'Power: 2'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Vampire'
#    'Berserker'
#
# 'Name: Fiery Temper'
# ('Text: Fiery Temper deals 3 damage to target creature or player.\n'
#  'Madness {R} (If you discard this card, discard it into exile. When you do, '
#  'cast it for its madness cost or put it into your graveyard.)')
# Types:
#    'Instant'
#
# 'Name: Flameblade Angel'
# ('Text: Flying\n'
#  'Whenever a source an opponent controls deals damage to you or a permanent '
#  "you control, you may have Flameblade Angel deal 1 damage to that source's "
#  'controller.')
# 'Power: 4'
# 'Toughness: 4'
# Types:
#    'Creature'
# Subtypes:
#    'Angel'
#
# 'Name: Gatstaf Arsonists'
# ('Text: At the beginning of each upkeep, if no spells were cast last turn, '
#  'transform Gatstaf Arsonists.')
# 'Power: 5'
# 'Toughness: 4'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Werewolf'
#
# 'Name: Gatstaf Ravagers'
# ("Text: Menace (This creature can't be blocked except by two or more "
#  'creatures.)\n'
#  'At the beginning of each upkeep, if a player cast two or more spells last '
#  'turn, transform Gatstaf Ravagers.')
# 'Power: 6'
# 'Toughness: 5'
# Types:
#    'Creature'
# Subtypes:
#    'Werewolf'
#
# 'Name: Geier Reach Bandit'
# ('Text: Haste\n'
#  'At the beginning of each upkeep, if no spells were cast last turn, transform '
#  'Geier Reach Bandit.')
# 'Power: 3'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Rogue'
#    'Werewolf'
#
# 'Name: Vildin-Pack Alpha'
# ('Text: Whenever a Werewolf enters the battlefield under your control, you may '
#  'transform it.\n'
#  'At the beginning of each upkeep, if a player cast two or more spells last '
#  'turn, transform Vildin-Pack Alpha.')
# 'Power: 4'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Werewolf'
#
# 'Name: Geistblast'
# ('Text: Geistblast deals 2 damage to target creature or player.\n'
#  '{2}{U}, Exile Geistblast from your graveyard: Copy target instant or sorcery '
#  'spell you control. You may choose new targets for the copy.')
# Types:
#    'Instant'
#
# 'Name: Gibbering Fiend'
# ('Text: When Gibbering Fiend enters the battlefield, it deals 1 damage to each '
#  'opponent.\n'
#  "Delirium â€” At the beginning of each opponent's upkeep, if there are four "
#  'or more card types among cards in your graveyard, Gibbering Fiend deals 1 '
#  'damage to that player.')
# 'Power: 2'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Devil'
#
# 'Name: Goldnight Castigator'
# ('Text: Flying, haste\n'
#  'If a source would deal damage to you, it deals double that damage to you '
#  'instead.\n'
#  'If a source would deal damage to Goldnight Castigator, it deals double that '
#  'damage to Goldnight Castigator instead.')
# 'Power: 4'
# 'Toughness: 9'
# Types:
#    'Creature'
# Subtypes:
#    'Angel'
#
# 'Name: Harness the Storm'
# ('Text: Whenever you cast an instant or sorcery spell from your hand, you may '
#  'cast target card with the same name as that spell from your graveyard. (You '
#  'still pay its costs.)')
# Types:
#    'Enchantment'
#
# 'Name: Howlpack Wolf'
# "Text: Howlpack Wolf can't block unless you control another Wolf or Werewolf."
# 'Power: 3'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Wolf'
#
# 'Name: Hulking Devil'
# 'Power: 5'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Devil'
#
# 'Name: Incorrigible Youths'
# ('Text: Haste\n'
#  'Madness {2}{R} (If you discard this card, discard it into exile. When you '
#  'do, cast it for its madness cost or put it into your graveyard.)')
# 'Power: 4'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Vampire'
#
# 'Name: Inner Struggle'
# 'Text: Target creature deals damage to itself equal to its power.'
# Types:
#    'Instant'
#
# 'Name: Insolent Neonate'
# ("Text: Menace (This creature can't be blocked except by two or more "
#  'creatures.)\n'
#  'Discard a card, Sacrifice Insolent Neonate: Draw a card.')
# 'Power: 1'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Vampire'
#
# 'Name: Kessig Forgemaster'
# ('Text: Whenever Kessig Forgemaster blocks or becomes blocked by a creature, '
#  'Kessig Forgemaster deals 1 damage to that creature.\n'
#  'At the beginning of each upkeep, if no spells were cast last turn, transform '
#  'Kessig Forgemaster.')
# 'Power: 2'
# 'Toughness: 1'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Shaman'
#    'Werewolf'
#
# 'Name: Flameheart Werewolf'
# ('Text: Whenever Flameheart Werewolf blocks or becomes blocked by a creature, '
#  'Flameheart Werewolf deals 2 damage to that creature.\n'
#  'At the beginning of each upkeep, if a player cast two or more spells last '
#  'turn, transform Flameheart Werewolf.')
# 'Power: 3'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Werewolf'
#
# 'Name: Lightning Axe'
# ('Text: As an additional cost to cast Lightning Axe, discard a card or pay '
#  '{5}.\n'
#  'Lightning Axe deals 5 damage to target creature.')
# Types:
#    'Instant'
#
# 'Name: Mad Prophet'
# 'Text: Haste\n{T}, Discard a card: Draw a card.'
# 'Power: 2'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Shaman'
#
# 'Name: Magmatic Chasm'
# "Text: Creatures without flying can't block this turn."
# Types:
#    'Sorcery'
#
# 'Name: Malevolent Whispers'
# ('Text: Gain control of target creature until end of turn. Untap that '
#  'creature. It gets +2/+0 and gains haste until end of turn. \n'
#  'Madness {3}{R} (If you discard this card, discard it into exile. When you '
#  'do, cast it for its madness cost or put it into your graveyard.)')
# Types:
#    'Sorcery'
#
# 'Name: Pyre Hound'
# ('Text: Trample\n'
#  'Whenever you cast an instant or sorcery spell, put a +1/+1 counter on Pyre '
#  'Hound.')
# 'Power: 2'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Elemental'
#    'Hound'
#
# 'Name: Ravenous Bloodseeker'
# 'Text: Discard a card: Ravenous Bloodseeker gets +2/-2 until end of turn.'
# 'Power: 1'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Vampire'
#    'Berserker'
#
# 'Name: Reduce to Ashes'
# ...
# ('Text: At the beginning of each upkeep, if no spells were cast last turn, '
#  'transform Solitary Hunter.')
# 'Power: 3'
# 'Toughness: 4'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Warrior'
#    'Werewolf'
#
# 'Name: One of the Pack'
# ('Text: At the beginning of each upkeep, if a player cast two or more spells '
#  'last turn, transform One of the Pack.')
# 'Power: 5'
# 'Toughness: 6'
# Types:
#    'Creature'
# Subtypes:
#    'Werewolf'
#
# 'Name: Soul Swallower'
# ('Text: Trample\n'
#  'Delirium â€” At the beginning of your upkeep, if there are four or more card '
#  'types among cards in your graveyard, put three +1/+1 counters on Soul '
#  'Swallower.')
# 'Power: 3'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Wurm'
#
# 'Name: Stoic Builder'
# ('Text: When Stoic Builder enters the battlefield, you may return target land '
#  'card from your graveyard to your hand.')
# 'Power: 2'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#
# 'Name: Thornhide Wolves'
# 'Power: 4'
# 'Toughness: 5'
# Types:
#    'Creature'
# Subtypes:
#    'Wolf'
#
# 'Name: Tireless Tracker'
# ('Text: Whenever a land enters the battlefield under your control, '
#  'investigate. (Put a colorless Clue artifact token onto the battlefield with '
#  '"{2}, Sacrifice this artifact: Draw a card.")\n'
#  'Whenever you sacrifice a Clue, put a +1/+1 counter on Tireless Tracker.')
# 'Power: 3'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Scout'
#
# 'Name: Traverse the Ulvenwald'
# ('Text: Search your library for a basic land card, reveal it, put it into your '
#  'hand, then shuffle your library.\n'
#  'Delirium â€” If there are four or more card types among cards in your '
#  'graveyard, instead search your library for a creature or land card, reveal '
#  'it, put it into your hand, then shuffle your library.')
# Types:
#    'Sorcery'
#
# 'Name: Ulvenwald Hydra'
# ('Text: Reach\n'
#  "Ulvenwald Hydra's power and toughness are each equal to the number of lands "
#  'you control.\n'
#  'When Ulvenwald Hydra enters the battlefield, you may search your library for '
#  'a land card, put it onto the battlefield tapped, then shuffle your library.')
# 'Power: *'
# 'Toughness: *'
# Types:
#    'Creature'
# Subtypes:
#    'Hydra'
#
# 'Name: Ulvenwald Mysteries'
# ('Text: Whenever a nontoken creature you control dies, investigate. (Put a '
#  'colorless Clue artifact token onto the battlefield with "{2}, Sacrifice this '
#  'artifact: Draw a card.")\n'
#  'Whenever you sacrifice a Clue, put a 1/1 white Human Soldier creature token '
#  'onto the battlefield.')
# Types:
#    'Enchantment'
#
# 'Name: Vessel of Nascency'
# ('Text: {1}{G}, Sacrifice Vessel of Nascency: Reveal the top four cards of '
#  'your library. You may put an artifact, creature, enchantment, land, or '
#  'planeswalker card from among them into your hand. Put the rest into your '
#  'graveyard.')
# Types:
#    'Enchantment'
#
# 'Name: Veteran Cathar'
# 'Text: {3}{W}: Target Human gains double strike until end of turn.'
# 'Power: 2'
# 'Toughness: 2'
# Types:
#    'Creature'
# Subtypes:
#    'Human'
#    'Soldier'
#
# 'Name: Watcher in the Web'
# ('Text: Reach (This creature can block creatures with flying.)\n'
#  'Watcher in the Web can block an additional seven creatures each combat.')
# 'Power: 2'
# 'Toughness: 5'
# Types:
#    'Creature'
# Subtypes:
#    'Spider'
#
# 'Name: Weirding Wood'
# ('Text: Enchant land\n'
#  'When Weirding Wood enters the battlefield, investigate. (Put a colorless '
#  'Clue artifact token onto the battlefield with "{2}, Sacrifice this artifact: '
#  'Draw a card.")\n'
#  'Enchanted land has "{T}: Add two mana of any one color to your mana pool."')
# Types:
#    'Enchantment'
# Subtypes:
#    'Aura'
#
# 'Name: Altered Ego'
# ("Text: Altered Ego can't be countered.\n"
#  'You may have Altered Ego enter the battlefield as a copy of any creature on '
#  'the battlefield, except it enters with X additional +1/+1 counters on it.')
# 'Power: 0'
# 'Toughness: 0'
# Types:
#    'Creature'
# Subtypes:
#    'Shapeshifter'
#
# 'Name: Anguished Unmaking'
# 'Text: Exile target nonland permanent. You lose 3 life.'
# Types:
#    'Instant'
#
# 'Name: Arlinn Kord'
# ('Text: +1: Until end of turn, up to one target creature gets +2/+2 and gains '
#  'vigilance and haste.\n'
#  '0: Put a 2/2 green Wolf creature token onto the battlefield. Transform '
#  'Arlinn Kord.')
# Types:
#    'Planeswalker'
# Subtypes:
#    'Arlinn'
#
# 'Name: Arlinn, Embraced by the Moon'
# ('Text: +1: Creatures you control get +1/+1 and gain trample until end of '
#  'turn.\n'
#  'âˆ’1: Arlinn, Embraced by the Moon deals 3 damage to target creature or '
#  'player. Transform Arlinn, Embraced by the Moon.\n'
#  'âˆ’6: You get an emblem with "Creatures you control have haste and â€˜{T}: '
#  'This creature deals damage equal to its power to target creature or '
#  'player.\'"')
# Types:
#    'Planeswalker'
# Subtypes:
#    'Arlinn'
#
# 'Name: Fevered Visions'
# ("Text: At the beginning of each player's end step, that player draws a card. "
#  'If the player is your opponent and has four or more cards in hand, Fevered '
#  'Visions deals 2 damage to him or her.')
# Types:
#    'Enchantment'
#
# 'Name: The Gitrog Monster'
# ('Text: Deathtouch\n'
#  'At the beginning of your upkeep, sacrifice The Gitrog Monster unless you '
#  'sacrifice a land.\n'
#  'You may play an additional land on each of your turns.\n'
#  'Whenever one or more land cards are put into your graveyard from anywhere, '
#  'draw a card.')
# 'Power: 6'
# 'Toughness: 6'
# Types:
#    'Creature'
# Subtypes:
#    'Frog'
#    'Horror'
#
# 'Name: Invocation of Saint Traft'
# ('Text: Enchant creature\n'
#  'Enchanted creature has "Whenever this creature attacks, put a 4/4 white '
#  'Angel creature token with flying onto the battlefield tapped and attacking. '
#  'Exile that token at end of combat."')
# Types:
#    'Enchantment'
# Subtypes:
#    'Aura'
#
# 'Name: Nahiri, the Harbinger'
# ('Text: +2: You may discard a card. If you do, draw a card.\n'
#  'âˆ’2: Exile target enchantment, tapped artifact, or tapped creature.\n'
#  'âˆ’8: Search your library for an artifact or creature card, put it onto the '
#  'battlefield, then shuffle your library. It gains haste. Return it to your '
#  'hand at the beginning of the next end step.')
# Types:
#    'Planeswalker'
# Subtypes:
#    'Nahiri'
#
# 'Name: Olivia, Mobilized for War'
# ('Text: Flying\n'
#  'Whenever another creature enters the battlefield under your control, you may '
#  'discard a card. If you do, put a +1/+1 counter on that creature, it gains '
#  'haste until end of turn, and it becomes a Vampire in addition to its other '
#  'types.')
# 'Power: 3'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Vampire'
#    'Knight'
#
# 'Name: Prized Amalgam'
# ('Text: Whenever a creature enters the battlefield, if it entered from your '
#  'graveyard or you cast it from your graveyard, return Prized Amalgam from '
#  'your graveyard to the battlefield tapped at the beginning of the next end '
#  'step.')
# 'Power: 3'
# 'Toughness: 3'
# Types:
#    'Creature'
# Subtypes:
#    'Zombie'
#
# "Name: Sigarda, Heron's Grace"
# ('Text: Flying\n'
#  'You and Humans you control have hexproof.\n'
#  '{2}, Exile a card from your graveyard: Put a 1/1 white Human Soldier '
#  'creature token onto the battlefield.')
# 'Power: 4'
# 'Toughness: 5'
# Types:
#    'Creature'
# Subtypes:
#    'Angel'
#
# 'Name: Sorin, Grim Nemesis'
# ('Text: +1: Reveal the top card of your library and put that card into your '
#  'hand. Each opponent loses life equal to its converted mana cost.\n'
#  'âˆ’X: Sorin, Grim Nemesis deals X damage to target creature or planeswalker '
#  'and you gain X life.\n'
#  'âˆ’9: Put a number of 1/1 black Vampire Knight creature tokens with lifelink '
#  'onto the battlefield equal to the highest life total among all players.')
# Types:
#    'Planeswalker'
# Subtypes:
#    'Sorin'
#
# 'Name: Brain in a Jar'
# ('Text: {1}, {T}: Put a charge counter on Brain in a Jar, then you may cast an '
#  'instant or sorcery card with converted mana cost equal to the number of '
#  'charge counters on Brain in a Jar from your hand without paying its mana '
#  'cost.\n'
#  '{3}, {T}, Remove X charge counters from Brain in a Jar: Scry X.')
# Types:
#    'Artifact'
#
# 'Name: Corrupted Grafstone'
# ('Text: Corrupted Grafstone enters the battlefield tapped.\n'
#  '{T}: Choose a color of a card in your graveyard. Add one mana of that color '
#  'to your mana pool.')
# Types:
#    'Artifact'
#
# 'Name: Epitaph Golem'
# 'Text: {2}: Put target card from your graveyard on the bottom of your library.'
# 'Power: 3'
# 'Toughness: 5'
# Types:
#    'Artifact'
#    'Creature'
# Subtypes:
#    'Golem'
#
# 'Name: Explosive Apparatus'
# ('Text: {3}, {T}, Sacrifice Explosive Apparatus: Explosive Apparatus deals 2 '
#  'damage to target creature or player.')
# Types:
#    'Artifact'
#
# 'Name: Harvest Hand'
# ('Text: When Harvest Hand dies, return it to the battlefield transformed under '
#  'your control.')
# 'Power: 2'
# 'Toughness: 2'
# Types:
#    'Artifact'
#    'Creature'
# Subtypes:
#    'Scarecrow'
#
# 'Name: Scrounged Scythe'
# ('Text: Equipped creature gets +1/+1.\n'
#  "As long as equipped creature is a Human, it has menace. (It can't be blocked "
#  'except by two or more creatures.)\n'
#  'Equip {2}')
# Types:
#    'Artifact'
# Subtypes:
#    'Equipment'
#
# 'Name: Haunted Cloak'
# 'Text: Equipped creature has vigilance, trample, and haste.\nEquip {1}'
# Types:
#    'Artifact'
# Subtypes:
#    'Equipment'
#
# 'Name: Magnifying Glass'
# ('Text: {T}: Add {C} to your mana pool.\n'
#  '{4}, {T}: Investigate. (Put a colorless Clue artifact token onto the '
#  'battlefield with "{2}, Sacrifice this artifact: Draw a card.")')
# Types:
#    'Artifact'
#
# "Name: Murderer's Axe"
# 'Text: Equipped creature gets +2/+2.\nEquipâ€”Discard a card.'
# Types:
#    'Artifact'
# Subtypes:
#    'Equipment'
#
# 'Name: Neglected Heirloom'
# ('Text: Equipped creature gets +1/+1.\n'
#  'When equipped creature transforms, transform Neglected Heirloom.\n'
#  'Equip {1}')
# Types:
#    'Artifact'
# Subtypes:
#    'Equipment'
#
# 'Name: Ashmouth Blade'
# 'Text: Equipped creature gets +3/+3 and has first strike.\nEquip {3}'
# Types:
#    'Artifact'
# Subtypes:
#    'Equipment'
#
# 'Name: Runaway Carriage'
# ('Text: Trample\n'
#  'When Runaway Carriage attacks or blocks, sacrifice it at end of combat.')
# 'Power: 5'
# 'Toughness: 6'
# Types:
#    'Artifact'
#    'Creature'
# Subtypes:
#    'Construct'
#
# 'Name: Shard of Broken Glass'
# ('Text: Equipped creature gets +1/+0.\n'
#  'Whenever equipped creature attacks, you may put the top two cards of your '
#  'library into your graveyard.\n'
#  'Equip {1} ({1}: Attach to target creature you control. Equip only as a '
#  'sorcery.)')
# Types:
#    'Artifact'
# Subtypes:
#    'Equipment'
#
# 'Name: Skeleton Key'
# ("Text: Equipped creature has skulk. (It can't be blocked by creatures with "
#  'greater power.)\n'
#  'Whenever equipped creature deals combat damage to a player, you may draw a '
#  'card. If you do, discard a card.\n'
#  'Equip {2}')
# Types:
#    'Artifact'
# Subtypes:
#    'Equipment'
#
# "Name: Slayer's Plate"
# ('Text: Equipped creature gets +4/+2.\n'
#  'Whenever equipped creature dies, if it was a Human, put a 1/1 white Spirit '
#  'creature token with flying onto the battlefield.\n'
#  'Equip {3}')
# Types:
#    'Artifact'
# Subtypes:
#    'Equipment'
#
# "Name: Tamiyo's Journal"
# ('Text: At the beginning of your upkeep, investigate. (Put a colorless Clue '
#  'artifact token onto the battlefield with "{2}, Sacrifice this artifact: Draw '
#  'a card.")\n'
#  '{T}, Sacrifice three Clues: Search your library for a card and put that card '
#  'into your hand. Then shuffle your library.')
# Types:
#    'Artifact'
#
# 'Name: Thraben Gargoyle'
# 'Text: Defender\n{6}: Transform Thraben Gargoyle.'
# 'Power: 2'
# 'Toughness: 2'
# Types:
#    'Artifact'
#    'Creature'
# Subtypes:
#    'Gargoyle'
#
# 'Name: Stonewing Antagonizer'
# 'Text: Flying'
# 'Power: 4'
# 'Toughness: 2'
# Types:
#    'Artifact'
#    'Creature'
# Subtypes:
#    'Gargoyle'
#    'Horror'
#
# 'Name: True-Faith Censer'
# ('Text: Equipped creature gets +1/+1 and has vigilance.\n'
#  'As long as equipped creature is a Human, it gets an additional +1/+0.\n'
#  'Equip {2} ({2}: Attach to target creature you control. Equip only as a '
#  'sorcery.)')
# Types:
#    'Artifact'
# Subtypes:
#    'Equipment'
#
# 'Name: Wicker Witch'
# 'Power: 3'
# 'Toughness: 1'
# Types:
#    'Artifact'
#    'Creature'
# Subtypes:
#    'Scarecrow'
#
# 'Name: Wild-Field Scarecrow'
# ('Text: Defender\n'
#  '{2}, Sacrifice Wild-Field Scarecrow: Search your library for up to two basic '
#  'land cards, reveal them, and put them into your hand. Then shuffle your '
#  'library.')
# 'Power: 1'
# 'Toughness: 4'
# Types:
#    'Artifact'
#    'Creature'
# Subtypes:
#    'Scarecrow'
#
# 'Name: Choked Estuary'
# ('Text: As Choked Estuary enters the battlefield, you may reveal an Island or '
#  "Swamp card from your hand. If you don't, Choked Estuary enters the "
#  'battlefield tapped.\n'
#  '{T}: Add {U} or {B} to your mana pool.')
# Types:
#    'Land'
#
# 'Name: Drownyard Temple'
# ('Text: {T}: Add {C} to your mana pool.\n'
#  '{3}: Return Drownyard Temple from your graveyard to the battlefield tapped.')
# Types:
#    'Land'
#
# 'Name: Foreboding Ruins'
# ('Text: As Foreboding Ruins enters the battlefield, you may reveal a Swamp or '
#  "Mountain card from your hand. If you don't, Foreboding Ruins enters the "
#  'battlefield tapped.\n'
#  '{T}: Add {B} or {R} to your mana pool.')
# Types:
#    'Land'
#
# 'Name: Forsaken Sanctuary'
# ('Text: Forsaken Sanctuary enters the battlefield tapped.\n'
#  '{T}: Add {W} or {B} to your mana pool.')
# Types:
#    'Land'
#
# 'Name: Fortified Village'
# ('Text: As Fortified Village enters the battlefield, you may reveal a Forest '
#  "or Plains card from your hand. If you don't, Fortified Village enters the "
#  'battlefield tapped.\n'
#  '{T}: Add {G} or {W} to your mana pool.')
# Types:
#    'Land'
#
# 'Name: Foul Orchard'
# ('Text: Foul Orchard enters the battlefield tapped.\n'
#  '{T}: Add {B} or {G} to your mana pool.')
# Types:
#    'Land'
#
# 'Name: Game Trail'
# ('Text: As Game Trail enters the battlefield, you may reveal a Mountain or '
#  "Forest card from your hand. If you don't, Game Trail enters the battlefield "
#  'tapped.\n'
#  '{T}: Add {R} or {G} to your mana pool.')
# Types:
#    'Land'
#
# 'Name: Highland Lake'
# ('Text: Highland Lake enters the battlefield tapped.\n'
#  '{T}: Add {U} or {R} to your mana pool.')
# Types:
#    'Land'
#
# 'Name: Port Town'
# ('Text: As Port Town enters the battlefield, you may reveal a Plains or Island '
#  "card from your hand. If you don't, Port Town enters the battlefield tapped.\n"
#  '{T}: Add {W} or {U} to your mana pool.')
# Types:
#    'Land'
#
# 'Name: Stone Quarry'
# ('Text: Stone Quarry enters the battlefield tapped.\n'
#  '{T}: Add {R} or {W} to your mana pool.')
# Types:
#    'Land'
#
# 'Name: Warped Landscape'
# ('Text: {T}: Add {C} to your mana pool.\n'
#  '{2}, {T}, Sacrifice Warped Landscape: Search your library for a basic land '
#  'card and put it onto the battlefield tapped. Then shuffle your library.')
# Types:
#    'Land'
#
# 'Name: Westvale Abbey'
# ('Text: {T}: Add {C} to your mana pool.\n'
#  '{5}, {T}, Pay 1 life: Put a 1/1 white and black Human Cleric creature token '
#  'onto the battlefield.\n'
#  '{5}, {T}, Sacrifice five creatures: Transform Westvale Abbey, then untap it.')
# Types:
#    'Land'
#
# 'Name: Ormendahl, Profane Prince'
# 'Text: Flying, lifelink, indestructible, haste'
# 'Power: 9'
# 'Toughness: 7'
# Types:
#    'Creature'
# Subtypes:
#    'Demon'
#
# 'Name: Woodland Stream'
# ('Text: Woodland Stream enters the battlefield tapped.\n'
#  '{T}: Add {G} or {U} to your mana pool.')
# Types:
#    'Land'
#
# 'Name: Plains'
# Types:
#    'Land'
# Subtypes:
#    'Plains'
#
# 'Name: Plains'
# Types:
#    'Land'
# Subtypes:
#    'Plains'
#
# 'Name: Plains'
# Types:
#    'Land'
# Subtypes:
#    'Plains'
#
# 'Name: Island'
# Types:
#    'Land'
# Subtypes:
#    'Island'
#
# 'Name: Island'
# Types:
#    'Land'
# Subtypes:
#    'Island'
#
# 'Name: Island'
# Types:
#    'Land'
# Subtypes:
#    'Island'
#
# 'Name: Swamp'
# Types:
#    'Land'
# Subtypes:
#    'Swamp'
#
# 'Name: Swamp'
# Types:
#    'Land'
# Subtypes:
#    'Swamp'
#
# 'Name: Swamp'
# Types:
#    'Land'
# Subtypes:
#    'Swamp'
#
# 'Name: Mountain'
# Types:
#    'Land'
# Subtypes:
#    'Mountain'
#
# 'Name: Mountain'
# Types:
#    'Land'
# Subtypes:
#    'Mountain'
#
# 'Name: Mountain'
# Types:
#    'Land'
# Subtypes:
#    'Mountain'
#
# 'Name: Forest'
# Types:
#    'Land'
# Subtypes:
#    'Forest'
#
# 'Name: Forest'
# Types:
#    'Land'
# Subtypes:
#    'Forest'
#
# 'Name: Forest'
# Types:
#    'Land'
# Subtypes:
#    'Forest'

# %%
for i in derps.values():
    if (i.get('supertypes') is not None):
        if ("Basic" in i["supertypes"]):
            pprint.pprint(i)

# %%
pprint.pprint(derps['Scepter of Empires'])
# Out:
# {'artist': 'John Avon',
#  'cmc': 3,
#  'flavor': '"With this scepter, smite your enemies."\nâ€”Scepter inscription',
#  'foreignNames': [{'language': 'Chinese Simplified',
#                    'multiverseid': 263093,
#                    'name': 'å¸�å›½æ�ƒæ�–'},
#                   {'language': 'Chinese Traditional',
#                    'multiverseid': 263342,
#                    'name': 'å¸�åœ‹æ¬Šæ�–'},
#                   {'language': 'French',
#                    'multiverseid': 263591,
#                    'name': "Sceptre d'empires"},
#                   {'language': 'German',
#                    'multiverseid': 263840,
#                    'name': 'Zepter der Kaiserreiche'},
#                   {'language': 'Italian',
#                    'multiverseid': 264089,
#                    'name': 'Scettro degli Imperi'},
#                   {'language': 'Japanese',
#                    'multiverseid': 264338,
#                    'name': 'å¸�å›½ã�®çŽ‹ç¬�'},
#                   {'language': 'Portuguese (Brazil)',
#                    'multiverseid': 264587,
#                    'name': 'Cetro dos ImpÃ©rios'},
#                   {'language': 'Russian',
#                    'multiverseid': 264836,
#                    'name': 'Ð¡ÐºÐ¸Ð¿ÐµÑ‚Ñ€ Ð˜Ð¼Ð¿ÐµÑ€Ð¸Ð¹'},
#                   {'language': 'Spanish',
#                    'multiverseid': 265085,
#                    'name': 'Cetro de los imperios'}],
#  'id': '94c493b78012e0abe8da20ce4307afa02e68fe09',
#  'imageName': 'scepter of empires',
#  'layout': 'normal',
#  'legalities': [{'format': 'Commander', 'legality': 'Legal'},
#                 {'format': 'Legacy', 'legality': 'Legal'},
#                 {'format': 'Modern', 'legality': 'Legal'},
#                 {'format': 'Vintage', 'legality': 'Legal'}],
#  'manaCost': '{3}',
#  'mciNumber': '216',
#  'multiverseid': 220209,
#  'name': 'Scepter of Empires',
#  'number': '216',
#  'originalText': '{T}: Scepter of Empires deals 1 damage to target player. It '
#                  'deals 3 damage to that player instead if you control '
#                  'artifacts named Crown of Empires and Throne of Empires.',
#  'originalType': 'Artifact',
#  'printings': ['M12'],
#  'rarity': 'Uncommon',
#  'rulings': [{'date': '2011-09-22',
#               'text': 'Whether or not you control the correct artifacts is '
#                       'determined when the ability resolves.'},
#              {'date': '2011-09-22',
#               'text': 'If any of the named cards stops being an artifact, it '
#                       'wonâ€™t be considered by these abilities.'}],
#  'text': '{T}: Scepter of Empires deals 1 damage to target player. It deals 3 '
#          'damage to that player instead if you control artifacts named Crown '
#          'of Empires and Throne of Empires.',
#  'type': 'Artifact',
#  'types': ['Artifact']}

# %% [markdown]
# ## Ideas para una formula de distancia:
#
# IDEAS TO IMPROVE ON THE DISTANCE FORMULA
#
# Check sub-types
# 	each subtype against each-other
# 	(Example: Human soldiers are more related to other human soldiers,
# 	compared to creatures that are only humans or soldiers)
#
# Check related effects (binary relation between cards, can go both ways)
#
# 	-'sacrifice target creature' : 'when this creature is sacrificed'/'when this creature dies'
#
# 	-'cards that can tap themselves' : 'cards that can untap other cards'
#
# 	-'discard X cards' : 'when this card is discarded, do Y'/card has 'madness'
#
# 	-'gain X' : 'whenever you gain X, do Y'
#
# 	-card has 'fabricate' : card is a 'token', card is an 'artifact'
#
# 	-card has 'first strike' : 'target creature gains +X/+X'
#
# 	-card depends on artifacts : card is an 'artifact'
# 		(example: draw 2 cards, then discard 1 unless you control an artifact)
#
# 	-'return target card to your hand' : 'Whenever X comes into play, do Y'
#
# 	-card has 'Landfall' : cards that can return lands to your hand
#
# 	- 'X you control gain Y' : cards of type 'X'
# 		(example: Elfs you control gain +1/+1)
#
# 	- 'X has Y as long as you control Z' : cards of type 'Z'
# 		(example: Eldrazi Aggressor has haste as long as you control another colorless creature)
#
# 	- 'X can't do Y unless you control Z' : cards of type 'Z'
# 		(same as above)
#
# 	Something worth pointing out: cards can have slight variations in how they're worded, yet
# 	they can still mean the same thing when it comes to checking properties. For example:
#
# 	'sacrifice target creature' or 'sacrifice all creatures you control' or 'sacrifice target permanent'
# 	are all functionally the same if you are trying to find cards that sacrifice your creatures
#
# Combinations that aren't so easy to process. These aren't so much of a binary relation,
# but rather a relation of a card to a set of cards (in this case, the set of cards is the library/deck):
#
# 	-cards that have 'Dredge' or 'Scavenge' are good on 'mill' decks (decks that constantly dump cards from your library into your graveyard)
#
# 	-cards that give you extra lands, or generate extra mana, are good on ramp decks (decks that rely on increasing your mana curve early into the game)
#
# 	-cards that burn life (Even at a minus to yourself) are good on burn decks that	rely on wining fast
#
# 	-cards that make you discard (usually the worst thing in a TCG) can be good on black decks, with creatures that prefer
# 	being on the discard pile, or trigger their effects when discarded (creatures with 'madness', for example)
#
# 	-cards with unusual, typically useless power/thoughness spreads (Example: 0/7 creature for 3 mana) can be good on decks that can buff stats, or invert them
#
# 	-cards that gain life aren't very good, unless there are monsters or spells that benefit on gaining/having a lot of health ('Whenever you gain life, put a +1/+1 counter on this monster' is an example of this)
#
# # DE AQUI EN ADELANTE NO SE HA AVANZADO EL REPORTE

# %%
# Aux variables
keeps = ['name', 'colors', 'types', 'cmc', 'power', 'toughness']

# Data fusion
mtg = []
for col in raw.columns.values:
    release = pd.DataFrame(raw[col]['cards'])
    release = release.loc[:, keeps]
    mtg.append(release)
mtg = pd.concat(mtg)

#Convertir 'power' y 'toughness' a valores numéricos
mtg[['power','toughness']] = mtg[['power','toughness']].apply(pd.to_numeric, errors='coerce')

#Eliminar datos con valores nulos
mtg = mtg.dropna()

#Convertir 'colors' y 'types' a su primer valor
f = lambda x: x[0]
mtg['colors'] = mtg['colors'].map(f)
mtg['types'] = mtg['types'].map(f)

#Tomar una muestra y describir los datos
mtgs = mtg.sample(10)
print(mtgs)
print(mtgs.describe())
# Out:
#                             name colors     types  cmc  power  toughness
# 256         Thousand-legged Kami  Green  Creature  8.0    6.0        6.0
# 48                Swamp Mosquito  Black  Creature  2.0    0.0        1.0
# 110     Jiwari, the Earth Aflame    Red  Creature  5.0    3.0        3.0
# 46             Aspiring Aeronaut   Blue  Creature  4.0    1.0        2.0
# 86            Fangren Pathcutter  Green  Creature  6.0    4.0        6.0
# 35     Erayo, Soratami Ascendant   Blue  Creature  2.0    1.0        1.0
# 13                         Guile   Blue  Creature  6.0    6.0        6.0
# 228  Rofellos, Llanowar Emissary  Green  Creature  2.0    2.0        1.0
# 166           Vorosh, the Hunter   Blue  Creature  6.0    6.0        6.0
# 99                Kragma Butcher    Red  Creature  3.0    2.0        3.0
#            cmc      power  toughness
# count  10.0000  10.000000   10.00000
# mean    4.4000   3.100000    3.50000
# std     2.1187   2.282786    2.27303
# min     2.0000   0.000000    1.00000
# 25%     2.2500   1.250000    1.25000
# 50%     4.5000   2.500000    3.00000
# 75%     6.0000   5.500000    6.00000
# max     8.0000   6.000000    6.00000

# %%
def gower(u, v, R):
    suma = 0
    if (u["colors"] != v["colors"]):
        suma += 1
    if (u["types"] != v["types"]):
        suma += 1
    #for t1 in u["subtypes"]:
    #    for t2 in v["subtypes"]:
    #        if (t1 == t2):
    #            suma += 1
    
    suma += np.abs(u["cmc"] - v["cmc"])/R['cmc']
    suma += np.abs(u["power"] - v["power"])/R['power']
    suma += np.abs(u["toughness"] - v["toughness"])/R['toughness']
    return suma

dms = np.zeros((mtgs['cmc'].count(), mtgs['cmc'].count()))
Rs = mtgs[['cmc', 'power','toughness']].max() - mtgs[['cmc', 'power','toughness']].min()
x = 0
for iu, u in mtgs.iterrows():
    y = 0
    for iv, v in mtgs.iterrows():
        dms[x][y] = gower(u, v, Rs)
        y += 1
    x += 1
print("\nMatriz redundante de distancias\n", dms)

#Convertir a matriz condensada
cdm = distance.squareform(dms)
print('\nMatriz condensada\n', cdm)

ZM = linkage(cdm, 'single')
print("\nEnlazamientos simples\n", ZM)

plt.figure(figsize=(12, 5))
dendrogram(ZM, labels = mtgs["name"].tolist(), leaf_rotation=75)
plt.show()
# Out:
# Matriz redundante de distancias
#  [[ 0.          4.          2.6         3.3         0.66666667  3.83333333
#    1.33333333  2.66666667  1.33333333  3.1       ]
#  [ 4.          0.          2.4         1.7         3.33333333  1.16666667
#    3.66666667  1.33333333  3.66666667  1.9       ]
#  [ 2.6         2.4         0.          1.7         1.93333333  2.23333333
#    2.26666667  2.06666667  2.26666667  0.5       ]
#  [ 3.3         1.7         1.7         0.          2.63333333  0.53333333
#    1.96666667  1.7         1.96666667  1.53333333]
#  [ 0.66666667  3.33333333  1.93333333  2.63333333  0.          3.16666667
#    1.33333333  2.          1.33333333  2.43333333]
#  [ 3.83333333  1.16666667  2.23333333  0.53333333  3.16666667  0.          2.5
#    1.16666667  2.5         1.73333333]
#  [ 1.33333333  3.66666667  2.26666667  1.96666667  1.33333333  2.5         0.
#    3.33333333  0.          2.76666667]
#  [ 2.66666667  1.33333333  2.06666667  1.7         2.          1.16666667
#    3.33333333  0.          3.33333333  1.56666667]
#  [ 1.33333333  3.66666667  2.26666667  1.96666667  1.33333333  2.5         0.
#    3.33333333  0.          2.76666667]
#  [ 3.1         1.9         0.5         1.53333333  2.43333333  1.73333333
#    2.76666667  1.56666667  2.76666667  0.        ]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-ad17f56b82a9> in <module>()
#      27
#      28 #Convertir a matriz condensada
# ---> 29 cdm = distance.squareform(dms)
#      30 print('\nMatriz condensada\n', cdm)
#      31
#
# NameError: name 'distance' is not defined

# %%
mtgl = mtg.sample(1000)
dml = np.zeros((mtgl['cmc'].count(), mtgl['cmc'].count()))
Rl = mtgl[['cmc', 'power','toughness']].max() - mtgl[['cmc', 'power','toughness']].min()
x = 0
for iu, u in mtgl.iterrows():
    y = 0
    for iv, v in mtgl.iterrows():
        dml[x][y] = gower(u, v, Rl)
        y += 1
    x += 1

cdml = distance.squareform(dml)
ZMl = linkage(cdml, 'single')

plt.figure(figsize=(12, 5))
dendrogram(ZMl, no_labels = True)
plt.show()

# %% [markdown]
# ###
